# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import scipy

# %%
device = "mps" if torch.backends.mps.is_available() else "cpu"
device = torch.device(device)
print('Using {} device'.format(device))
#device = torch.device("cpu")
# Out:
# Using mps device

# %%
X_test = np.load("X_test.npy")
# X_test = scipy.stats.zscore(X_test, axis=1)
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
# X_train_valid = scipy.stats.zscore(X_train_valid, axis=1)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")
y_test -= 769
y_train_valid -= 769

# %%
train_valid_1_idx = list(np.where(person_train_valid==1)[0])
X_train_valid_1 = X_train_valid[train_valid_1_idx]
y_train_valid_1 = y_train_valid[train_valid_1_idx]
test_1_idx = list(np.where(person_test==1)[0])
X_test_1 = X_test[test_1_idx]
y_test_1 = y_test[test_1_idx]

# %%
print(X_train_valid_1.shape)
print(X_train_valid_1.shape[0]*0.2)
# Out:
# (236, 22, 1000)
# 47.2

# %%
idx_val = np.random.choice(236, 47, replace=False)
idx_tra = np.array(list(set(range(236)).difference(set(idx_val))))
X_train, X_val = X_train_valid_1[idx_tra], X_train_valid_1[idx_val] 
y_train, y_val = y_train_valid_1[idx_tra], y_train_valid_1[idx_val]
X_test = X_test_1
y_test = y_test_1

# %% [markdown]
# ### Shape of data

# %%
print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (50, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (50,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %% [markdown]
# # To torch.tensor

# %%
X_train = torch.from_numpy(X_train).float()
X_train = X_train[:,None,:,:]
y_train = torch.from_numpy(y_train).long()
X_val = torch.from_numpy(X_val).float()
X_val = X_val[:,None,:,:]
y_val = torch.from_numpy(y_val).long()
X_test = torch.from_numpy(X_test).float()
X_test = X_test[:,None,:,:]
y_test = torch.from_numpy(y_test).long()

# %% [markdown]
# # Dataset Class

# %%
train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
val_dataset = torch.utils.data.TensorDataset(X_val, y_val)
test_dataset = torch.utils.data.TensorDataset(X_test, y_test)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# # Network

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        #nn.Conv2d(in_channels, out_channels, kernel_size)
        #input:(C,H,W)=(1,22,1000)
        self.conv1 = nn.Conv2d(1, 32, 3, padding='same') #(32,22,1000)
        self.conv2 = nn.Conv2d(32, 32, 3, padding='same')
        self.pool1 = nn.MaxPool2d((2,2))  #(32,11,500)
        self.bn1   = nn.BatchNorm2d(32) #(32,11,500)
        
        self.conv3 = nn.Conv2d(32, 16, 3, padding='same') #(16,11,500)
        self.conv4 = nn.Conv2d(16, 16, 3, padding='same')
        self.pool2 = nn.MaxPool2d((1,2))  #(16,11,250)
        self.bn2   = nn.BatchNorm2d(16) #(16,11,250)
        
        self.conv5 = nn.Conv2d(16, 8, 5, padding='same') #(8,11,250)
        self.conv6 = nn.Conv2d(8, 8, 3, padding='same')
        self.pool3 = nn.MaxPool2d((1,2))  #(8,11,125)
        self.bn3   = nn.BatchNorm2d(8) #(8,11,125)

        self.conv7 = nn.Conv2d(8, 4, 5, padding='same') #(4,11,125)
        self.conv8 = nn.Conv2d(4, 4, 3, padding='same')
        self.pool4 = nn.AvgPool2d((1,5))  #(4,11,25)
        self.bn4   = nn.BatchNorm2d(4) #(4,11,25)
        
        self.fc1 = nn.Linear(4*11*25,256)
        self.fc2 = nn.Linear(256,64)
        self.fc3 = nn.Linear(64,16)
        self.fc4 = nn.Linear(16, 4)
        
        self.sm = nn.Softmax(dim=1)
        
        #non-linear
        self.nonlinear = nn.ELU()
        #Dropout
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.nonlinear(self.bn1(self.pool1(self.conv2(self.conv1(x)))))
        x = self.dropout(x)
        x = self.nonlinear(self.bn2(self.pool2(self.conv4(self.conv3(x)))))
        x = self.dropout(x)
        x = self.nonlinear(self.bn3(self.pool3(self.conv6(self.conv5(x)))))
        x = self.dropout(x)
        x = self.nonlinear(self.bn4(self.pool4(self.conv8(self.conv7(x)))))
        x = self.dropout(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)
        x = self.sm(x)
        return x

# %%
def train_epoch(model, optimizer, criterion, dataloader):
    train_loss = 0
    train_acc = 0
    model.train()
    for i, (inp, labels) in enumerate(dataloader):
        inp, labels = inp.to(device), labels.to(device)
        optimizer.zero_grad()
        outp = model(inp)
        outp_pred = torch.max(outp,axis=1).indices
        train_acc += torch.sum(outp_pred == labels)
        loss = criterion(outp, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss = train_loss / len(train_dataloader.dataset)
    train_acc = train_acc/ len(train_dataloader.dataset)
    return train_loss, train_acc

# %%
def predict(model, optimizer, criterion, dataloader, pred_loader=test_dataloader):
    test_loss = 0
    test_acc = 0
    best_acc = 0
    model.eval()
    with torch.no_grad():
        for i, (inp, labels) in enumerate(pred_loader):
            inp, labels = inp.to(device), labels.to(device)
            outp = model(inp)
            outp_pred = torch.max(outp,axis=1).indices
            test_acc += torch.sum(outp_pred == labels)
            loss = criterion(outp, labels)
            test_loss += loss.item()
        test_loss = test_loss / len(pred_loader.dataset)
        test_acc = test_acc / len(pred_loader.dataset)
    return test_loss, test_acc

# %%
acc_device = torch.device('cpu')
def run(num_epochs, optimizer, criterion, pred_loader=test_dataloader):
    train_loss_list = []
    test_loss_list = []
    train_acc_list = []
    test_acc_list = []
    best_acc = 0
    for epoch in range(num_epochs):
        train_loss, train_acc = train_epoch(model, optimizer, criterion, train_dataloader)
        test_loss, test_acc = predict(model, optimizer, criterion, pred_loader)
        # if epoch % 5 == 0:
        #     print(f'Epoch [{epoch+1}], train_Loss : {train_loss:.4f}, val_Loss : {test_loss:.4f},\
        #         train_accuracy : {100*train_acc:.4f}%, val_accuracy : {100*test_acc:.4f}%')
        print(f'Epoch [{epoch+1}], train_Loss : {train_loss:.4f}, val_Loss : {test_loss:.4f},\
                train_accuracy : {100*train_acc:.4f}%, val_accuracy : {100*test_acc:.4f}%')
        train_loss_list.append(train_loss)
        test_loss_list.append(test_loss)
        train_acc_list.append(train_acc.to(acc_device))
        test_acc_list.append(test_acc.to(acc_device))

        if test_acc > best_acc and pred_loader != test_dataloader:
            torch.save(model.state_dict(), 'CNN1st_model_subject1.pt')
            best_acc = test_acc
    return train_loss_list, test_loss_list, train_acc_list, test_acc_list

# %%
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
train_loss_list, test_loss_list, train_acc_list, test_acc_list = run(200, optimizer, criterion, val_dataloader)
# Out:
# Epoch [1], train_Loss : 0.0439, val_Loss : 0.0558,                train_accuracy : 24.3386%, val_accuracy : 16.0000%
# Epoch [2], train_Loss : 0.0434, val_Loss : 0.0556,                train_accuracy : 33.3333%, val_accuracy : 20.0000%
# Epoch [3], train_Loss : 0.0418, val_Loss : 0.0549,                train_accuracy : 43.9153%, val_accuracy : 36.0000%
# Epoch [4], train_Loss : 0.0398, val_Loss : 0.0536,                train_accuracy : 48.6772%, val_accuracy : 36.0000%
# Epoch [5], train_Loss : 0.0387, val_Loss : 0.0540,                train_accuracy : 52.3810%, val_accuracy : 34.0000%
# Epoch [6], train_Loss : 0.0367, val_Loss : 0.0541,                train_accuracy : 56.6138%, val_accuracy : 34.0000%
# Epoch [7], train_Loss : 0.0368, val_Loss : 0.0542,                train_accuracy : 58.7302%, val_accuracy : 34.0000%
# Epoch [8], train_Loss : 0.0358, val_Loss : 0.0576,                train_accuracy : 61.9048%, val_accuracy : 28.0000%
# Epoch [9], train_Loss : 0.0348, val_Loss : 0.0532,                train_accuracy : 64.5503%, val_accuracy : 38.0000%
# Epoch [10], train_Loss : 0.0335, val_Loss : 0.0579,                train_accuracy : 68.7831%, val_accuracy : 26.0000%
# Epoch [11], train_Loss : 0.0345, val_Loss : 0.0559,                train_accuracy : 66.1376%, val_accuracy : 30.0000%
# Epoch [12], train_Loss : 0.0334, val_Loss : 0.0565,                train_accuracy : 69.3122%, val_accuracy : 24.0000%
# Epoch [13], train_Loss : 0.0336, val_Loss : 0.0569,                train_accuracy : 69.3122%, val_accuracy : 24.0000%
# Epoch [14], train_Loss : 0.0331, val_Loss : 0.0555,                train_accuracy : 69.8413%, val_accuracy : 36.0000%
# Epoch [15], train_Loss : 0.0318, val_Loss : 0.0558,                train_accuracy : 73.5450%, val_accuracy : 34.0000%
# Epoch [16], train_Loss : 0.0333, val_Loss : 0.0554,                train_accuracy : 67.7249%, val_accuracy : 34.0000%
# Epoch [17], train_Loss : 0.0324, val_Loss : 0.0550,                train_accuracy : 71.9577%, val_accuracy : 34.0000%
# Epoch [18], train_Loss : 0.0325, val_Loss : 0.0564,                train_accuracy : 70.8995%, val_accuracy : 30.0000%
# Epoch [19], train_Loss : 0.0319, val_Loss : 0.0554,                train_accuracy : 74.6032%, val_accuracy : 34.0000%
# Epoch [20], train_Loss : 0.0313, val_Loss : 0.0563,                train_accuracy : 77.2487%, val_accuracy : 26.0000%
# Epoch [21], train_Loss : 0.0313, val_Loss : 0.0578,                train_accuracy : 76.1905%, val_accuracy : 28.0000%
# Epoch [22], train_Loss : 0.0316, val_Loss : 0.0573,                train_accuracy : 74.0741%, val_accuracy : 26.0000%
# Epoch [23], train_Loss : 0.0320, val_Loss : 0.0558,                train_accuracy : 74.0741%, val_accuracy : 32.0000%
# Epoch [24], train_Loss : 0.0329, val_Loss : 0.0528,                train_accuracy : 69.8413%, val_accuracy : 36.0000%
# Epoch [25], train_Loss : 0.0318, val_Loss : 0.0550,                train_accuracy : 73.5450%, val_accuracy : 36.0000%
# Epoch [26], train_Loss : 0.0315, val_Loss : 0.0548,                train_accuracy : 75.6614%, val_accuracy : 30.0000%
# Epoch [27], train_Loss : 0.0310, val_Loss : 0.0558,                train_accuracy : 76.1905%, val_accuracy : 32.0000%
# Epoch [28], train_Loss : 0.0323, val_Loss : 0.0548,                train_accuracy : 71.9577%, val_accuracy : 34.0000%
# Epoch [29], train_Loss : 0.0319, val_Loss : 0.0558,                train_accuracy : 74.6032%, val_accuracy : 36.0000%
# Epoch [30], train_Loss : 0.0319, val_Loss : 0.0575,                train_accuracy : 73.0159%, val_accuracy : 30.0000%
# Epoch [31], train_Loss : 0.0303, val_Loss : 0.0537,                train_accuracy : 77.2487%, val_accuracy : 40.0000%
# Epoch [32], train_Loss : 0.0311, val_Loss : 0.0535,                train_accuracy : 75.6614%, val_accuracy : 42.0000%
# Epoch [33], train_Loss : 0.0333, val_Loss : 0.0545,                train_accuracy : 67.1958%, val_accuracy : 34.0000%
# Epoch [34], train_Loss : 0.0317, val_Loss : 0.0546,                train_accuracy : 74.6032%, val_accuracy : 36.0000%
# Epoch [35], train_Loss : 0.0309, val_Loss : 0.0576,                train_accuracy : 78.3069%, val_accuracy : 32.0000%
# Epoch [36], train_Loss : 0.0305, val_Loss : 0.0564,                train_accuracy : 78.3069%, val_accuracy : 30.0000%
# Epoch [37], train_Loss : 0.0307, val_Loss : 0.0565,                train_accuracy : 77.7778%, val_accuracy : 34.0000%
# Epoch [38], train_Loss : 0.0306, val_Loss : 0.0569,                train_accuracy : 76.7196%, val_accuracy : 34.0000%
# Epoch [39], train_Loss : 0.0311, val_Loss : 0.0577,                train_accuracy : 76.1905%, val_accuracy : 30.0000%
# Epoch [40], train_Loss : 0.0301, val_Loss : 0.0550,                train_accuracy : 80.4233%, val_accuracy : 38.0000%
# Epoch [41], train_Loss : 0.0305, val_Loss : 0.0529,                train_accuracy : 78.3069%, val_accuracy : 40.0000%
# Epoch [42], train_Loss : 0.0300, val_Loss : 0.0533,                train_accuracy : 78.3069%, val_accuracy : 40.0000%
# Epoch [43], train_Loss : 0.0304, val_Loss : 0.0553,                train_accuracy : 78.8360%, val_accuracy : 38.0000%
# Epoch [44], train_Loss : 0.0298, val_Loss : 0.0552,                train_accuracy : 80.4233%, val_accuracy : 32.0000%
# Epoch [45], train_Loss : 0.0293, val_Loss : 0.0570,                train_accuracy : 81.4815%, val_accuracy : 30.0000%
# Epoch [46], train_Loss : 0.0297, val_Loss : 0.0567,                train_accuracy : 80.9524%, val_accuracy : 30.0000%
# Epoch [47], train_Loss : 0.0298, val_Loss : 0.0574,                train_accuracy : 81.4815%, val_accuracy : 32.0000%
# Epoch [48], train_Loss : 0.0300, val_Loss : 0.0556,                train_accuracy : 80.4233%, val_accuracy : 36.0000%
# Epoch [49], train_Loss : 0.0294, val_Loss : 0.0576,                train_accuracy : 81.4815%, val_accuracy : 30.0000%
# Epoch [50], train_Loss : 0.0304, val_Loss : 0.0548,                train_accuracy : 77.2487%, val_accuracy : 38.0000%
# Epoch [51], train_Loss : 0.0305, val_Loss : 0.0543,                train_accuracy : 77.7778%, val_accuracy : 40.0000%
# Epoch [52], train_Loss : 0.0306, val_Loss : 0.0563,                train_accuracy : 78.3069%, val_accuracy : 32.0000%
# Epoch [53], train_Loss : 0.0289, val_Loss : 0.0560,                train_accuracy : 84.1270%, val_accuracy : 34.0000%
# Epoch [54], train_Loss : 0.0299, val_Loss : 0.0558,                train_accuracy : 80.4233%, val_accuracy : 36.0000%
# Epoch [55], train_Loss : 0.0293, val_Loss : 0.0537,                train_accuracy : 82.5397%, val_accuracy : 42.0000%
# Epoch [56], train_Loss : 0.0287, val_Loss : 0.0551,                train_accuracy : 83.5979%, val_accuracy : 36.0000%
# Epoch [57], train_Loss : 0.0288, val_Loss : 0.0545,                train_accuracy : 82.5397%, val_accuracy : 38.0000%
# Epoch [58], train_Loss : 0.0305, val_Loss : 0.0542,                train_accuracy : 77.7778%, val_accuracy : 40.0000%
# Epoch [59], train_Loss : 0.0295, val_Loss : 0.0553,                train_accuracy : 80.9524%, val_accuracy : 32.0000%
# Epoch [60], train_Loss : 0.0283, val_Loss : 0.0556,                train_accuracy : 85.7143%, val_accuracy : 36.0000%
# Epoch [61], train_Loss : 0.0288, val_Loss : 0.0588,                train_accuracy : 82.5397%, val_accuracy : 26.0000%
# Epoch [62], train_Loss : 0.0292, val_Loss : 0.0572,                train_accuracy : 82.5397%, val_accuracy : 28.0000%
# Epoch [63], train_Loss : 0.0297, val_Loss : 0.0541,                train_accuracy : 79.8942%, val_accuracy : 34.0000%
# Epoch [64], train_Loss : 0.0288, val_Loss : 0.0528,                train_accuracy : 84.1270%, val_accuracy : 42.0000%
# Epoch [65], train_Loss : 0.0283, val_Loss : 0.0560,                train_accuracy : 84.6561%, val_accuracy : 32.0000%
# Epoch [66], train_Loss : 0.0282, val_Loss : 0.0544,                train_accuracy : 84.6561%, val_accuracy : 38.0000%
# Epoch [67], train_Loss : 0.0279, val_Loss : 0.0509,                train_accuracy : 86.2434%, val_accuracy : 44.0000%
# Epoch [68], train_Loss : 0.0299, val_Loss : 0.0517,                train_accuracy : 80.4233%, val_accuracy : 42.0000%
# Epoch [69], train_Loss : 0.0278, val_Loss : 0.0511,                train_accuracy : 86.2434%, val_accuracy : 42.0000%
# Epoch [70], train_Loss : 0.0275, val_Loss : 0.0503,                train_accuracy : 88.3598%, val_accuracy : 42.0000%
# Epoch [71], train_Loss : 0.0281, val_Loss : 0.0540,                train_accuracy : 86.2434%, val_accuracy : 40.0000%
# Epoch [72], train_Loss : 0.0286, val_Loss : 0.0530,                train_accuracy : 83.0688%, val_accuracy : 42.0000%
# Epoch [73], train_Loss : 0.0292, val_Loss : 0.0523,                train_accuracy : 81.4815%, val_accuracy : 46.0000%
# Epoch [74], train_Loss : 0.0292, val_Loss : 0.0552,                train_accuracy : 82.5397%, val_accuracy : 36.0000%
# Epoch [75], train_Loss : 0.0292, val_Loss : 0.0559,                train_accuracy : 81.4815%, val_accuracy : 38.0000%
# Epoch [76], train_Loss : 0.0291, val_Loss : 0.0564,                train_accuracy : 83.0688%, val_accuracy : 36.0000%
# Epoch [77], train_Loss : 0.0290, val_Loss : 0.0542,                train_accuracy : 83.0688%, val_accuracy : 40.0000%
# Epoch [78], train_Loss : 0.0290, val_Loss : 0.0527,                train_accuracy : 83.0688%, val_accuracy : 38.0000%
# Epoch [79], train_Loss : 0.0282, val_Loss : 0.0517,                train_accuracy : 85.1852%, val_accuracy : 42.0000%
# Epoch [80], train_Loss : 0.0272, val_Loss : 0.0510,                train_accuracy : 89.4180%, val_accuracy : 48.0000%
# Epoch [81], train_Loss : 0.0280, val_Loss : 0.0516,                train_accuracy : 86.2434%, val_accuracy : 44.0000%
# Epoch [82], train_Loss : 0.0272, val_Loss : 0.0530,                train_accuracy : 87.8307%, val_accuracy : 38.0000%
# Epoch [83], train_Loss : 0.0285, val_Loss : 0.0530,                train_accuracy : 84.6561%, val_accuracy : 42.0000%
# Epoch [84], train_Loss : 0.0288, val_Loss : 0.0512,                train_accuracy : 83.0688%, val_accuracy : 44.0000%
# Epoch [85], train_Loss : 0.0272, val_Loss : 0.0507,                train_accuracy : 88.8889%, val_accuracy : 46.0000%
# Epoch [86], train_Loss : 0.0279, val_Loss : 0.0523,                train_accuracy : 86.2434%, val_accuracy : 46.0000%
# Epoch [87], train_Loss : 0.0284, val_Loss : 0.0542,                train_accuracy : 84.6561%, val_accuracy : 44.0000%
# Epoch [88], train_Loss : 0.0284, val_Loss : 0.0528,                train_accuracy : 84.6561%, val_accuracy : 40.0000%
# Epoch [89], train_Loss : 0.0287, val_Loss : 0.0527,                train_accuracy : 83.0688%, val_accuracy : 42.0000%
# Epoch [90], train_Loss : 0.0284, val_Loss : 0.0540,                train_accuracy : 84.6561%, val_accuracy : 42.0000%
# Epoch [91], train_Loss : 0.0280, val_Loss : 0.0530,                train_accuracy : 85.7143%, val_accuracy : 46.0000%
# Epoch [92], train_Loss : 0.0294, val_Loss : 0.0544,                train_accuracy : 81.4815%, val_accuracy : 36.0000%
# Epoch [93], train_Loss : 0.0276, val_Loss : 0.0545,                train_accuracy : 87.3016%, val_accuracy : 36.0000%
# Epoch [94], train_Loss : 0.0274, val_Loss : 0.0520,                train_accuracy : 87.8307%, val_accuracy : 38.0000%
# Epoch [95], train_Loss : 0.0280, val_Loss : 0.0516,                train_accuracy : 85.1852%, val_accuracy : 44.0000%
# Epoch [96], train_Loss : 0.0266, val_Loss : 0.0529,                train_accuracy : 89.9471%, val_accuracy : 46.0000%
# Epoch [97], train_Loss : 0.0282, val_Loss : 0.0520,                train_accuracy : 85.1852%, val_accuracy : 42.0000%
# Epoch [98], train_Loss : 0.0279, val_Loss : 0.0520,                train_accuracy : 86.2434%, val_accuracy : 42.0000%
# Epoch [99], train_Loss : 0.0266, val_Loss : 0.0519,                train_accuracy : 90.4762%, val_accuracy : 42.0000%
# Epoch [100], train_Loss : 0.0274, val_Loss : 0.0534,                train_accuracy : 88.3598%, val_accuracy : 44.0000%
# Epoch [101], train_Loss : 0.0268, val_Loss : 0.0514,                train_accuracy : 89.4180%, val_accuracy : 42.0000%
# Epoch [102], train_Loss : 0.0279, val_Loss : 0.0507,                train_accuracy : 86.2434%, val_accuracy : 48.0000%
# Epoch [103], train_Loss : 0.0279, val_Loss : 0.0504,                train_accuracy : 86.2434%, val_accuracy : 44.0000%
# Epoch [104], train_Loss : 0.0268, val_Loss : 0.0520,                train_accuracy : 91.0053%, val_accuracy : 42.0000%
# Epoch [105], train_Loss : 0.0281, val_Loss : 0.0542,                train_accuracy : 85.7143%, val_accuracy : 40.0000%
# Epoch [106], train_Loss : 0.0273, val_Loss : 0.0539,                train_accuracy : 87.8307%, val_accuracy : 42.0000%
# Epoch [107], train_Loss : 0.0278, val_Loss : 0.0524,                train_accuracy : 87.3016%, val_accuracy : 42.0000%
# Epoch [108], train_Loss : 0.0274, val_Loss : 0.0513,                train_accuracy : 87.8307%, val_accuracy : 42.0000%
# Epoch [109], train_Loss : 0.0287, val_Loss : 0.0544,                train_accuracy : 83.5979%, val_accuracy : 36.0000%
# Epoch [110], train_Loss : 0.0281, val_Loss : 0.0555,                train_accuracy : 85.1852%, val_accuracy : 36.0000%
# Epoch [111], train_Loss : 0.0273, val_Loss : 0.0547,                train_accuracy : 88.3598%, val_accuracy : 38.0000%
# Epoch [112], train_Loss : 0.0279, val_Loss : 0.0533,                train_accuracy : 86.2434%, val_accuracy : 38.0000%
# Epoch [113], train_Loss : 0.0278, val_Loss : 0.0540,                train_accuracy : 86.7725%, val_accuracy : 36.0000%
# Epoch [114], train_Loss : 0.0289, val_Loss : 0.0545,                train_accuracy : 82.0106%, val_accuracy : 34.0000%
# Epoch [115], train_Loss : 0.0286, val_Loss : 0.0543,                train_accuracy : 83.5979%, val_accuracy : 42.0000%
# Epoch [116], train_Loss : 0.0283, val_Loss : 0.0511,                train_accuracy : 86.2434%, val_accuracy : 46.0000%
# Epoch [117], train_Loss : 0.0265, val_Loss : 0.0520,                train_accuracy : 91.0053%, val_accuracy : 44.0000%
# Epoch [118], train_Loss : 0.0278, val_Loss : 0.0547,                train_accuracy : 86.2434%, val_accuracy : 40.0000%
# Epoch [119], train_Loss : 0.0302, val_Loss : 0.0563,                train_accuracy : 78.8360%, val_accuracy : 32.0000%
# Epoch [120], train_Loss : 0.0270, val_Loss : 0.0561,                train_accuracy : 88.8889%, val_accuracy : 36.0000%
# Epoch [121], train_Loss : 0.0292, val_Loss : 0.0522,                train_accuracy : 83.0688%, val_accuracy : 44.0000%
# Epoch [122], train_Loss : 0.0280, val_Loss : 0.0501,                train_accuracy : 85.1852%, val_accuracy : 48.0000%
# Epoch [123], train_Loss : 0.0288, val_Loss : 0.0524,                train_accuracy : 83.0688%, val_accuracy : 46.0000%
# Epoch [124], train_Loss : 0.0293, val_Loss : 0.0526,                train_accuracy : 81.4815%, val_accuracy : 38.0000%
# Epoch [125], train_Loss : 0.0286, val_Loss : 0.0549,                train_accuracy : 84.1270%, val_accuracy : 36.0000%
# Epoch [126], train_Loss : 0.0289, val_Loss : 0.0543,                train_accuracy : 83.5979%, val_accuracy : 36.0000%
# Epoch [127], train_Loss : 0.0297, val_Loss : 0.0535,                train_accuracy : 80.9524%, val_accuracy : 42.0000%
# Epoch [128], train_Loss : 0.0295, val_Loss : 0.0553,                train_accuracy : 80.9524%, val_accuracy : 36.0000%
# Epoch [129], train_Loss : 0.0298, val_Loss : 0.0537,                train_accuracy : 80.9524%, val_accuracy : 40.0000%
# Epoch [130], train_Loss : 0.0283, val_Loss : 0.0543,                train_accuracy : 85.1852%, val_accuracy : 38.0000%
# Epoch [131], train_Loss : 0.0282, val_Loss : 0.0546,                train_accuracy : 85.1852%, val_accuracy : 38.0000%
# Epoch [132], train_Loss : 0.0278, val_Loss : 0.0509,                train_accuracy : 86.2434%, val_accuracy : 42.0000%
# Epoch [133], train_Loss : 0.0280, val_Loss : 0.0527,                train_accuracy : 86.7725%, val_accuracy : 42.0000%
# Epoch [134], train_Loss : 0.0271, val_Loss : 0.0535,                train_accuracy : 88.3598%, val_accuracy : 40.0000%
# Epoch [135], train_Loss : 0.0278, val_Loss : 0.0541,                train_accuracy : 86.7725%, val_accuracy : 38.0000%
# Epoch [136], train_Loss : 0.0272, val_Loss : 0.0546,                train_accuracy : 88.8889%, val_accuracy : 36.0000%
# Epoch [137], train_Loss : 0.0266, val_Loss : 0.0552,                train_accuracy : 89.9471%, val_accuracy : 36.0000%
# Epoch [138], train_Loss : 0.0283, val_Loss : 0.0555,                train_accuracy : 85.1852%, val_accuracy : 36.0000%
# Epoch [139], train_Loss : 0.0274, val_Loss : 0.0541,                train_accuracy : 87.3016%, val_accuracy : 40.0000%
# Epoch [140], train_Loss : 0.0275, val_Loss : 0.0535,                train_accuracy : 87.3016%, val_accuracy : 40.0000%
# Epoch [141], train_Loss : 0.0276, val_Loss : 0.0501,                train_accuracy : 86.2434%, val_accuracy : 46.0000%
# Epoch [142], train_Loss : 0.0273, val_Loss : 0.0529,                train_accuracy : 88.3598%, val_accuracy : 40.0000%
# Epoch [143], train_Loss : 0.0286, val_Loss : 0.0527,                train_accuracy : 84.1270%, val_accuracy : 42.0000%
# Epoch [144], train_Loss : 0.0278, val_Loss : 0.0533,                train_accuracy : 86.7725%, val_accuracy : 40.0000%
# Epoch [145], train_Loss : 0.0267, val_Loss : 0.0542,                train_accuracy : 89.9471%, val_accuracy : 40.0000%
# Epoch [146], train_Loss : 0.0283, val_Loss : 0.0526,                train_accuracy : 85.7143%, val_accuracy : 38.0000%
# Epoch [147], train_Loss : 0.0274, val_Loss : 0.0544,                train_accuracy : 88.3598%, val_accuracy : 38.0000%
# Epoch [148], train_Loss : 0.0279, val_Loss : 0.0535,                train_accuracy : 86.7725%, val_accuracy : 42.0000%
# Epoch [149], train_Loss : 0.0283, val_Loss : 0.0547,                train_accuracy : 84.6561%, val_accuracy : 40.0000%
# Epoch [150], train_Loss : 0.0262, val_Loss : 0.0547,                train_accuracy : 92.0635%, val_accuracy : 40.0000%
# Epoch [151], train_Loss : 0.0278, val_Loss : 0.0531,                train_accuracy : 86.7725%, val_accuracy : 40.0000%
# Epoch [152], train_Loss : 0.0277, val_Loss : 0.0536,                train_accuracy : 86.7725%, val_accuracy : 36.0000%
# Epoch [153], train_Loss : 0.0276, val_Loss : 0.0547,                train_accuracy : 87.3016%, val_accuracy : 36.0000%
# Epoch [154], train_Loss : 0.0278, val_Loss : 0.0518,                train_accuracy : 86.2434%, val_accuracy : 44.0000%
# Epoch [155], train_Loss : 0.0271, val_Loss : 0.0516,                train_accuracy : 89.4180%, val_accuracy : 44.0000%
# Epoch [156], train_Loss : 0.0272, val_Loss : 0.0531,                train_accuracy : 88.8889%, val_accuracy : 42.0000%
# Epoch [157], train_Loss : 0.0288, val_Loss : 0.0538,                train_accuracy : 83.0688%, val_accuracy : 40.0000%
# Epoch [158], train_Loss : 0.0279, val_Loss : 0.0547,                train_accuracy : 85.7143%, val_accuracy : 38.0000%
# Epoch [159], train_Loss : 0.0272, val_Loss : 0.0557,                train_accuracy : 88.8889%, val_accuracy : 32.0000%
# Epoch [160], train_Loss : 0.0279, val_Loss : 0.0563,                train_accuracy : 86.2434%, val_accuracy : 34.0000%
# Epoch [161], train_Loss : 0.0280, val_Loss : 0.0544,                train_accuracy : 85.1852%, val_accuracy : 42.0000%
# Epoch [162], train_Loss : 0.0266, val_Loss : 0.0535,                train_accuracy : 90.4762%, val_accuracy : 42.0000%
# Epoch [163], train_Loss : 0.0269, val_Loss : 0.0549,                train_accuracy : 89.4180%, val_accuracy : 44.0000%
# Epoch [164], train_Loss : 0.0275, val_Loss : 0.0552,                train_accuracy : 87.3016%, val_accuracy : 38.0000%
# Epoch [165], train_Loss : 0.0275, val_Loss : 0.0538,                train_accuracy : 87.8307%, val_accuracy : 38.0000%
# Epoch [166], train_Loss : 0.0274, val_Loss : 0.0541,                train_accuracy : 88.3598%, val_accuracy : 40.0000%
# Epoch [167], train_Loss : 0.0280, val_Loss : 0.0536,                train_accuracy : 85.7143%, val_accuracy : 38.0000%
# Epoch [168], train_Loss : 0.0276, val_Loss : 0.0510,                train_accuracy : 87.3016%, val_accuracy : 44.0000%
# Epoch [169], train_Loss : 0.0271, val_Loss : 0.0493,                train_accuracy : 88.8889%, val_accuracy : 52.0000%
# Epoch [170], train_Loss : 0.0273, val_Loss : 0.0507,                train_accuracy : 87.8307%, val_accuracy : 46.0000%
# Epoch [171], train_Loss : 0.0273, val_Loss : 0.0518,                train_accuracy : 87.8307%, val_accuracy : 42.0000%
# Epoch [172], train_Loss : 0.0276, val_Loss : 0.0525,                train_accuracy : 86.7725%, val_accuracy : 42.0000%
# Epoch [173], train_Loss : 0.0280, val_Loss : 0.0545,                train_accuracy : 86.2434%, val_accuracy : 40.0000%
# Epoch [174], train_Loss : 0.0273, val_Loss : 0.0521,                train_accuracy : 88.3598%, val_accuracy : 38.0000%
# Epoch [175], train_Loss : 0.0274, val_Loss : 0.0528,                train_accuracy : 88.3598%, val_accuracy : 40.0000%
# Epoch [176], train_Loss : 0.0258, val_Loss : 0.0537,                train_accuracy : 93.1217%, val_accuracy : 42.0000%
# Epoch [177], train_Loss : 0.0270, val_Loss : 0.0502,                train_accuracy : 88.8889%, val_accuracy : 46.0000%
# Epoch [178], train_Loss : 0.0282, val_Loss : 0.0548,                train_accuracy : 85.1852%, val_accuracy : 36.0000%
# Epoch [179], train_Loss : 0.0270, val_Loss : 0.0547,                train_accuracy : 88.8889%, val_accuracy : 40.0000%
# Epoch [180], train_Loss : 0.0272, val_Loss : 0.0554,                train_accuracy : 87.8307%, val_accuracy : 38.0000%
# Epoch [181], train_Loss : 0.0280, val_Loss : 0.0543,                train_accuracy : 85.7143%, val_accuracy : 38.0000%
# Epoch [182], train_Loss : 0.0267, val_Loss : 0.0540,                train_accuracy : 90.4762%, val_accuracy : 38.0000%
# Epoch [183], train_Loss : 0.0270, val_Loss : 0.0511,                train_accuracy : 88.8889%, val_accuracy : 48.0000%
# Epoch [184], train_Loss : 0.0263, val_Loss : 0.0510,                train_accuracy : 91.5344%, val_accuracy : 48.0000%
# Epoch [185], train_Loss : 0.0269, val_Loss : 0.0523,                train_accuracy : 88.3598%, val_accuracy : 44.0000%
# Epoch [186], train_Loss : 0.0270, val_Loss : 0.0536,                train_accuracy : 88.8889%, val_accuracy : 42.0000%
# Epoch [187], train_Loss : 0.0275, val_Loss : 0.0501,                train_accuracy : 87.3016%, val_accuracy : 48.0000%
# Epoch [188], train_Loss : 0.0269, val_Loss : 0.0503,                train_accuracy : 89.4180%, val_accuracy : 52.0000%
# Epoch [189], train_Loss : 0.0275, val_Loss : 0.0499,                train_accuracy : 87.3016%, val_accuracy : 48.0000%
# Epoch [190], train_Loss : 0.0273, val_Loss : 0.0502,                train_accuracy : 87.3016%, val_accuracy : 48.0000%
# Epoch [191], train_Loss : 0.0275, val_Loss : 0.0521,                train_accuracy : 87.3016%, val_accuracy : 42.0000%
# Epoch [192], train_Loss : 0.0268, val_Loss : 0.0547,                train_accuracy : 89.9471%, val_accuracy : 36.0000%
# Epoch [193], train_Loss : 0.0276, val_Loss : 0.0528,                train_accuracy : 87.8307%, val_accuracy : 42.0000%
# Epoch [194], train_Loss : 0.0265, val_Loss : 0.0506,                train_accuracy : 90.4762%, val_accuracy : 46.0000%
# Epoch [195], train_Loss : 0.0272, val_Loss : 0.0509,                train_accuracy : 88.8889%, val_accuracy : 46.0000%
# Epoch [196], train_Loss : 0.0266, val_Loss : 0.0510,                train_accuracy : 90.4762%, val_accuracy : 48.0000%
# Epoch [197], train_Loss : 0.0275, val_Loss : 0.0497,                train_accuracy : 87.8307%, val_accuracy : 48.0000%
# Epoch [198], train_Loss : 0.0262, val_Loss : 0.0517,                train_accuracy : 92.0635%, val_accuracy : 50.0000%
# Epoch [199], train_Loss : 0.0266, val_Loss : 0.0497,                train_accuracy : 91.0053%, val_accuracy : 50.0000%
# Epoch [200], train_Loss : 0.0265, val_Loss : 0.0498,                train_accuracy : 90.4762%, val_accuracy : 50.0000%

# %%
model = CNN().to(device)
model.load_state_dict(torch.load('CNN1st_model_subject1.pt'))
model.eval()
test_loss, test_acc = predict(model, optimizer, criterion, test_dataloader)

print(f'Test_Loss : {test_loss:.4f},Test_Accuracy : {100*test_acc:.4f}%')
# Out:
# Test_Loss : 0.0477,Test_Accuracy : 52.0000%

# %%
num_epochs = 200
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)
ax.plot(range(num_epochs), train_loss_list, c='b', label='train loss')
ax.plot(range(num_epochs), test_loss_list, c='r', label='val loss')
ax.set_xlabel('epoch', fontsize='20')
ax.set_ylabel('loss', fontsize='20')
ax.set_title('train and val loss', fontsize='20')
ax.grid()
ax.legend(fontsize='25')
plt.show()

# %%
num_epochs = 200
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)
ax.plot(range(num_epochs), train_acc_list, c='b', label='train accuracy')
ax.plot(range(num_epochs), test_acc_list, c='r', label='val accuracy')
ax.set_xlabel('epoch', fontsize='20')
ax.set_ylabel('loss', fontsize='20')
ax.set_title('train and val accuracy', fontsize='20')
ax.grid()
ax.legend(fontsize='25')
plt.show()
