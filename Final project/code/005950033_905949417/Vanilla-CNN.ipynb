# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import scipy

# %%
device = "mps" if torch.backends.mps.is_available() else "cpu"
device = torch.device(device)
print('Using {} device'.format(device))
# Out:
# Using mps device

# %%
X_test = np.load("X_test.npy")
# X_test = scipy.stats.zscore(X_test, axis=1)
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
# X_train_valid = scipy.stats.zscore(X_train_valid, axis=1)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")
y_test -= 769
y_train_valid -= 769

# %%
idx_val = np.random.choice(2115, 423, replace=False)
idx_tra = np.array(list(set(range(2115)).difference(set(idx_val))))
X_train, X_val = X_train_valid[idx_tra], X_train_valid[idx_val] 
y_train, y_val = y_train_valid[idx_tra], y_train_valid[idx_val]

# %% [markdown]
# ### Shape of data

# %%
print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %% [markdown]
# # To torch.tensor

# %%
X_train = torch.from_numpy(X_train).float()
X_train = X_train[:,None,:,:]
y_train = torch.from_numpy(y_train).long()
X_val = torch.from_numpy(X_val).float()
X_val = X_val[:,None,:,:]
y_val = torch.from_numpy(y_val).long()
X_test = torch.from_numpy(X_test).float()
X_test = X_test[:,None,:,:]
y_test = torch.from_numpy(y_test).long()

# %% [markdown]
# # Dataset Class

# %%
train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
val_dataset = torch.utils.data.TensorDataset(X_val, y_val)
test_dataset = torch.utils.data.TensorDataset(X_test, y_test)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# # Network

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        #nn.Conv2d(in_channels, out_channels, kernel_size)
        #input:(C,H,W)=(1,22,1000)
        self.conv1 = nn.Conv2d(1, 32, 3, padding='same') #(32,22,1000)
        self.conv2 = nn.Conv2d(32, 32, 3, padding='same')
        self.pool1 = nn.MaxPool2d((2,2))  #(32,11,500)
        self.bn1   = nn.BatchNorm2d(32) #(32,11,500)
        
        self.conv3 = nn.Conv2d(32, 16, 3, padding='same') #(16,11,500)
        self.conv4 = nn.Conv2d(16, 16, 3, padding='same')
        self.pool2 = nn.MaxPool2d((1,2))  #(16,11,250)
        self.bn2   = nn.BatchNorm2d(16) #(16,11,250)
        
        self.conv5 = nn.Conv2d(16, 8, 5, padding='same') #(8,11,250)
        self.conv6 = nn.Conv2d(8, 8, 3, padding='same')
        self.pool3 = nn.MaxPool2d((1,2))  #(8,11,125)
        self.bn3   = nn.BatchNorm2d(8) #(8,11,125)

        self.conv7 = nn.Conv2d(8, 4, 5, padding='same') #(4,11,125)
        self.conv8 = nn.Conv2d(4, 4, 3, padding='same')
        self.pool4 = nn.AvgPool2d((1,5))  #(4,11,25)
        self.bn4   = nn.BatchNorm2d(4) #(4,11,25)
        
        self.fc1 = nn.Linear(4*11*25,256)
        self.fc2 = nn.Linear(256,64)
        self.fc3 = nn.Linear(64,16)
        self.fc4 = nn.Linear(16, 4)
        
        self.sm = nn.Softmax(dim=1)
        
        #non-linear
        self.nonlinear = nn.ELU()
        #Dropout
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.nonlinear(self.bn1(self.pool1(self.conv2(self.conv1(x)))))
        x = self.dropout(x)
        x = self.nonlinear(self.bn2(self.pool2(self.conv4(self.conv3(x)))))
        x = self.dropout(x)
        x = self.nonlinear(self.bn3(self.pool3(self.conv6(self.conv5(x)))))
        x = self.dropout(x)
        x = self.nonlinear(self.bn4(self.pool4(self.conv8(self.conv7(x)))))
        x = self.dropout(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)
        x = self.sm(x)
        return x

# %%
def train_epoch(model, optimizer, criterion, dataloader):
    train_loss = 0
    train_acc = 0
    model.train()
    for i, (inp, labels) in enumerate(dataloader):
        inp, labels = inp.to(device), labels.to(device)
        optimizer.zero_grad()
        outp = model(inp)
        outp_pred = torch.max(outp,axis=1).indices
        train_acc += torch.sum(outp_pred == labels)
        loss = criterion(outp, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss = train_loss / len(train_dataloader.dataset)
    train_acc = train_acc/ len(train_dataloader.dataset)
    return train_loss, train_acc

# %%
def predict(model, optimizer, criterion, dataloader, pred_loader=test_dataloader):
    test_loss = 0
    test_acc = 0
    best_acc = 0
    model.eval()
    with torch.no_grad():
        for i, (inp, labels) in enumerate(pred_loader):
            inp, labels = inp.to(device), labels.to(device)
            outp = model(inp)
            outp_pred = torch.max(outp,axis=1).indices
            test_acc += torch.sum(outp_pred == labels)
            loss = criterion(outp, labels)
            test_loss += loss.item()
        test_loss = test_loss / len(pred_loader.dataset)
        test_acc = test_acc / len(pred_loader.dataset)
    return test_loss, test_acc

# %%
def run(num_epochs, optimizer, criterion, pred_loader=test_dataloader):
    train_loss_list = []
    test_loss_list = []
    best_acc = 0
    for epoch in range(num_epochs):
        train_loss, train_acc = train_epoch(model, optimizer, criterion, train_dataloader)
        test_loss, test_acc = predict(model, optimizer, criterion, pred_loader)
        if epoch % 5 == 0:
            print(f'Epoch [{epoch+1}], train_Loss : {train_loss:.4f}, val_Loss : {test_loss:.4f},\
                train_accuracy : {100*train_acc:.4f}%, val_accuracy : {100*test_acc:.4f}%')
        train_loss_list.append(train_loss)
        test_loss_list.append(test_loss)

        if test_acc > best_acc and pred_loader != test_dataloader:
            torch.save(model.state_dict(), 'CNN_model.pt')
            best_acc = test_acc
    return train_loss_list, test_loss_list

# %%
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
train_loss_list, test_loss_list = run(1000, optimizer, criterion, val_dataloader)
# Out:
# Epoch [1], train_Loss : 0.0423, val_Loss : 0.0411,                train_accuracy : 33.3333%, val_accuracy : 39.7291%
# Epoch [6], train_Loss : 0.0375, val_Loss : 0.0399,                train_accuracy : 52.9551%, val_accuracy : 46.7269%
# Epoch [11], train_Loss : 0.0374, val_Loss : 0.0396,                train_accuracy : 53.4870%, val_accuracy : 46.5011%
# Epoch [16], train_Loss : 0.0364, val_Loss : 0.0385,                train_accuracy : 56.8558%, val_accuracy : 50.7901%
# Epoch [21], train_Loss : 0.0369, val_Loss : 0.0386,                train_accuracy : 55.2601%, val_accuracy : 51.0158%
# Epoch [26], train_Loss : 0.0354, val_Loss : 0.0382,                train_accuracy : 60.5201%, val_accuracy : 53.0474%
# Epoch [31], train_Loss : 0.0349, val_Loss : 0.0380,                train_accuracy : 62.0567%, val_accuracy : 52.8217%
# Epoch [36], train_Loss : 0.0353, val_Loss : 0.0385,                train_accuracy : 60.4610%, val_accuracy : 50.5643%
# Epoch [41], train_Loss : 0.0349, val_Loss : 0.0382,                train_accuracy : 62.0567%, val_accuracy : 52.3702%
# Epoch [46], train_Loss : 0.0343, val_Loss : 0.0383,                train_accuracy : 63.9480%, val_accuracy : 52.5959%
# Epoch [51], train_Loss : 0.0345, val_Loss : 0.0380,                train_accuracy : 63.2388%, val_accuracy : 52.8217%
# Epoch [56], train_Loss : 0.0346, val_Loss : 0.0371,                train_accuracy : 63.0024%, val_accuracy : 55.7562%
# Epoch [61], train_Loss : 0.0341, val_Loss : 0.0378,                train_accuracy : 64.3617%, val_accuracy : 53.9503%
# Epoch [66], train_Loss : 0.0344, val_Loss : 0.0373,                train_accuracy : 63.7116%, val_accuracy : 55.5305%
# Epoch [71], train_Loss : 0.0351, val_Loss : 0.0379,                train_accuracy : 61.5839%, val_accuracy : 53.4989%
# Epoch [76], train_Loss : 0.0341, val_Loss : 0.0375,                train_accuracy : 64.8936%, val_accuracy : 54.8533%
# Epoch [81], train_Loss : 0.0342, val_Loss : 0.0376,                train_accuracy : 64.6572%, val_accuracy : 54.1761%
# Epoch [86], train_Loss : 0.0343, val_Loss : 0.0379,                train_accuracy : 64.1844%, val_accuracy : 53.9503%
# Epoch [91], train_Loss : 0.0334, val_Loss : 0.0376,                train_accuracy : 67.6123%, val_accuracy : 54.6275%
# Epoch [96], train_Loss : 0.0341, val_Loss : 0.0380,                train_accuracy : 65.1300%, val_accuracy : 53.9503%
# Epoch [101], train_Loss : 0.0339, val_Loss : 0.0372,                train_accuracy : 65.7801%, val_accuracy : 55.9819%
# Epoch [106], train_Loss : 0.0337, val_Loss : 0.0373,                train_accuracy : 66.4303%, val_accuracy : 55.7562%
# Epoch [111], train_Loss : 0.0337, val_Loss : 0.0384,                train_accuracy : 66.2530%, val_accuracy : 52.3702%
# Epoch [116], train_Loss : 0.0345, val_Loss : 0.0375,                train_accuracy : 63.7707%, val_accuracy : 55.3047%
# Epoch [121], train_Loss : 0.0337, val_Loss : 0.0367,                train_accuracy : 66.6667%, val_accuracy : 58.4650%
# Epoch [126], train_Loss : 0.0338, val_Loss : 0.0375,                train_accuracy : 66.1939%, val_accuracy : 55.0790%
# Epoch [131], train_Loss : 0.0338, val_Loss : 0.0376,                train_accuracy : 66.0757%, val_accuracy : 54.8533%
# Epoch [136], train_Loss : 0.0342, val_Loss : 0.0375,                train_accuracy : 64.8345%, val_accuracy : 55.0790%
# Epoch [141], train_Loss : 0.0340, val_Loss : 0.0374,                train_accuracy : 65.5437%, val_accuracy : 55.3047%
# Epoch [146], train_Loss : 0.0336, val_Loss : 0.0366,                train_accuracy : 66.8440%, val_accuracy : 58.0135%
# Epoch [151], train_Loss : 0.0338, val_Loss : 0.0386,                train_accuracy : 65.9574%, val_accuracy : 51.4673%
# Epoch [156], train_Loss : 0.0343, val_Loss : 0.0373,                train_accuracy : 64.7754%, val_accuracy : 55.9819%
# Epoch [161], train_Loss : 0.0334, val_Loss : 0.0376,                train_accuracy : 67.4941%, val_accuracy : 54.6275%
# Epoch [166], train_Loss : 0.0337, val_Loss : 0.0377,                train_accuracy : 66.4303%, val_accuracy : 55.3047%
# Epoch [171], train_Loss : 0.0338, val_Loss : 0.0377,                train_accuracy : 66.3712%, val_accuracy : 55.3047%
# Epoch [176], train_Loss : 0.0347, val_Loss : 0.0383,                train_accuracy : 63.3570%, val_accuracy : 52.5959%
# Epoch [181], train_Loss : 0.0342, val_Loss : 0.0379,                train_accuracy : 65.3664%, val_accuracy : 54.4018%
# Epoch [186], train_Loss : 0.0341, val_Loss : 0.0374,                train_accuracy : 65.6028%, val_accuracy : 55.7562%
# Epoch [191], train_Loss : 0.0336, val_Loss : 0.0379,                train_accuracy : 66.8440%, val_accuracy : 53.7246%
# Epoch [196], train_Loss : 0.0341, val_Loss : 0.0377,                train_accuracy : 65.3073%, val_accuracy : 54.8533%
# Epoch [201], train_Loss : 0.0346, val_Loss : 0.0369,                train_accuracy : 63.8889%, val_accuracy : 57.3363%
# Epoch [206], train_Loss : 0.0337, val_Loss : 0.0375,                train_accuracy : 66.6076%, val_accuracy : 55.7562%
# Epoch [211], train_Loss : 0.0337, val_Loss : 0.0375,                train_accuracy : 66.7849%, val_accuracy : 55.5305%
# Epoch [216], train_Loss : 0.0340, val_Loss : 0.0379,                train_accuracy : 65.8983%, val_accuracy : 54.6275%
# Epoch [221], train_Loss : 0.0347, val_Loss : 0.0378,                train_accuracy : 63.5934%, val_accuracy : 54.4018%
# Epoch [226], train_Loss : 0.0342, val_Loss : 0.0371,                train_accuracy : 65.3073%, val_accuracy : 57.1106%
# Epoch [231], train_Loss : 0.0348, val_Loss : 0.0377,                train_accuracy : 63.1206%, val_accuracy : 54.8533%
# Epoch [236], train_Loss : 0.0340, val_Loss : 0.0385,                train_accuracy : 65.6619%, val_accuracy : 51.9187%
# Epoch [241], train_Loss : 0.0338, val_Loss : 0.0369,                train_accuracy : 66.3712%, val_accuracy : 57.3363%
# Epoch [246], train_Loss : 0.0347, val_Loss : 0.0383,                train_accuracy : 63.5934%, val_accuracy : 53.0474%
# Epoch [251], train_Loss : 0.0339, val_Loss : 0.0377,                train_accuracy : 65.8983%, val_accuracy : 54.1761%
# Epoch [256], train_Loss : 0.0347, val_Loss : 0.0383,                train_accuracy : 63.5934%, val_accuracy : 52.8217%
# Epoch [261], train_Loss : 0.0337, val_Loss : 0.0379,                train_accuracy : 66.6076%, val_accuracy : 54.1761%
# Epoch [266], train_Loss : 0.0351, val_Loss : 0.0375,                train_accuracy : 62.1158%, val_accuracy : 55.5305%
# Epoch [271], train_Loss : 0.0348, val_Loss : 0.0369,                train_accuracy : 63.2979%, val_accuracy : 57.1106%
# Epoch [276], train_Loss : 0.0343, val_Loss : 0.0374,                train_accuracy : 64.5390%, val_accuracy : 55.7562%
# Epoch [281], train_Loss : 0.0345, val_Loss : 0.0384,                train_accuracy : 64.0662%, val_accuracy : 52.3702%
# Epoch [286], train_Loss : 0.0349, val_Loss : 0.0374,                train_accuracy : 63.0024%, val_accuracy : 55.7562%
# Epoch [291], train_Loss : 0.0352, val_Loss : 0.0382,                train_accuracy : 61.7612%, val_accuracy : 53.2731%
# Epoch [296], train_Loss : 0.0343, val_Loss : 0.0381,                train_accuracy : 64.9527%, val_accuracy : 53.4989%
# Epoch [301], train_Loss : 0.0341, val_Loss : 0.0382,                train_accuracy : 65.1891%, val_accuracy : 53.4989%
# Epoch [306], train_Loss : 0.0346, val_Loss : 0.0390,                train_accuracy : 63.9480%, val_accuracy : 50.7901%
# Epoch [311], train_Loss : 0.0349, val_Loss : 0.0381,                train_accuracy : 62.9433%, val_accuracy : 53.7246%
# Epoch [316], train_Loss : 0.0341, val_Loss : 0.0377,                train_accuracy : 65.5437%, val_accuracy : 55.0790%
# Epoch [321], train_Loss : 0.0357, val_Loss : 0.0393,                train_accuracy : 60.4019%, val_accuracy : 49.8871%
# Epoch [326], train_Loss : 0.0346, val_Loss : 0.0383,                train_accuracy : 63.7116%, val_accuracy : 53.2731%
# Epoch [331], train_Loss : 0.0349, val_Loss : 0.0377,                train_accuracy : 62.9433%, val_accuracy : 55.0790%
# Epoch [336], train_Loss : 0.0347, val_Loss : 0.0384,                train_accuracy : 63.4752%, val_accuracy : 52.8217%
# Epoch [341], train_Loss : 0.0353, val_Loss : 0.0377,                train_accuracy : 61.4657%, val_accuracy : 55.0790%
# Epoch [346], train_Loss : 0.0345, val_Loss : 0.0389,                train_accuracy : 64.1253%, val_accuracy : 50.7901%
# Epoch [351], train_Loss : 0.0352, val_Loss : 0.0395,                train_accuracy : 61.7612%, val_accuracy : 48.9842%
# Epoch [356], train_Loss : 0.0340, val_Loss : 0.0381,                train_accuracy : 65.7210%, val_accuracy : 54.1761%
# Epoch [361], train_Loss : 0.0356, val_Loss : 0.0393,                train_accuracy : 60.5792%, val_accuracy : 49.8871%
# Epoch [366], train_Loss : 0.0354, val_Loss : 0.0392,                train_accuracy : 61.3475%, val_accuracy : 50.1129%
# Epoch [371], train_Loss : 0.0353, val_Loss : 0.0369,                train_accuracy : 61.5839%, val_accuracy : 57.3363%
# Epoch [376], train_Loss : 0.0365, val_Loss : 0.0395,                train_accuracy : 57.8605%, val_accuracy : 49.2099%
# Epoch [381], train_Loss : 0.0356, val_Loss : 0.0399,                train_accuracy : 60.5792%, val_accuracy : 48.3070%
# Epoch [386], train_Loss : 0.0348, val_Loss : 0.0378,                train_accuracy : 63.0615%, val_accuracy : 54.6275%
# Epoch [391], train_Loss : 0.0352, val_Loss : 0.0380,                train_accuracy : 61.7021%, val_accuracy : 53.9503%
# Epoch [396], train_Loss : 0.0347, val_Loss : 0.0385,                train_accuracy : 63.4752%, val_accuracy : 52.3702%
# Epoch [401], train_Loss : 0.0363, val_Loss : 0.0376,                train_accuracy : 58.2742%, val_accuracy : 55.3047%
# Epoch [406], train_Loss : 0.0352, val_Loss : 0.0393,                train_accuracy : 61.9385%, val_accuracy : 49.6614%
# Epoch [411], train_Loss : 0.0353, val_Loss : 0.0374,                train_accuracy : 61.7612%, val_accuracy : 55.9819%
# Epoch [416], train_Loss : 0.0372, val_Loss : 0.0416,                train_accuracy : 55.4965%, val_accuracy : 42.4379%
# Epoch [421], train_Loss : 0.0365, val_Loss : 0.0396,                train_accuracy : 58.0378%, val_accuracy : 48.9842%
# Epoch [426], train_Loss : 0.0350, val_Loss : 0.0393,                train_accuracy : 62.7069%, val_accuracy : 49.6614%
# Epoch [431], train_Loss : 0.0354, val_Loss : 0.0381,                train_accuracy : 61.4657%, val_accuracy : 53.7246%
# Epoch [436], train_Loss : 0.0348, val_Loss : 0.0383,                train_accuracy : 63.2388%, val_accuracy : 52.8217%
# Epoch [441], train_Loss : 0.0346, val_Loss : 0.0371,                train_accuracy : 63.8889%, val_accuracy : 57.3363%
# Epoch [446], train_Loss : 0.0349, val_Loss : 0.0382,                train_accuracy : 63.0024%, val_accuracy : 53.2731%
# Epoch [451], train_Loss : 0.0357, val_Loss : 0.0383,                train_accuracy : 60.3428%, val_accuracy : 53.0474%
# Epoch [456], train_Loss : 0.0359, val_Loss : 0.0386,                train_accuracy : 59.7518%, val_accuracy : 52.3702%
# Epoch [461], train_Loss : 0.0361, val_Loss : 0.0392,                train_accuracy : 59.1017%, val_accuracy : 50.5643%
# Epoch [466], train_Loss : 0.0361, val_Loss : 0.0378,                train_accuracy : 59.1608%, val_accuracy : 54.6275%
# Epoch [471], train_Loss : 0.0354, val_Loss : 0.0377,                train_accuracy : 61.1702%, val_accuracy : 55.0790%
# Epoch [476], train_Loss : 0.0356, val_Loss : 0.0382,                train_accuracy : 60.5792%, val_accuracy : 53.0474%
# Epoch [481], train_Loss : 0.0349, val_Loss : 0.0372,                train_accuracy : 62.7660%, val_accuracy : 56.6591%
# Epoch [486], train_Loss : 0.0369, val_Loss : 0.0398,                train_accuracy : 56.3239%, val_accuracy : 48.5327%
# Epoch [491], train_Loss : 0.0355, val_Loss : 0.0376,                train_accuracy : 61.1111%, val_accuracy : 55.0790%
# Epoch [496], train_Loss : 0.0353, val_Loss : 0.0388,                train_accuracy : 61.5248%, val_accuracy : 51.4673%
# Epoch [501], train_Loss : 0.0354, val_Loss : 0.0391,                train_accuracy : 61.2884%, val_accuracy : 50.5643%
# Epoch [506], train_Loss : 0.0355, val_Loss : 0.0386,                train_accuracy : 60.8747%, val_accuracy : 52.3702%
# Epoch [511], train_Loss : 0.0349, val_Loss : 0.0376,                train_accuracy : 62.8251%, val_accuracy : 55.3047%
# Epoch [516], train_Loss : 0.0357, val_Loss : 0.0381,                train_accuracy : 60.4019%, val_accuracy : 53.9503%
# Epoch [521], train_Loss : 0.0359, val_Loss : 0.0376,                train_accuracy : 59.8109%, val_accuracy : 55.3047%
# Epoch [526], train_Loss : 0.0353, val_Loss : 0.0383,                train_accuracy : 61.5839%, val_accuracy : 53.2731%
# Epoch [531], train_Loss : 0.0358, val_Loss : 0.0389,                train_accuracy : 59.8700%, val_accuracy : 51.4673%
# Epoch [536], train_Loss : 0.0351, val_Loss : 0.0387,                train_accuracy : 62.2340%, val_accuracy : 51.4673%
# Epoch [541], train_Loss : 0.0358, val_Loss : 0.0393,                train_accuracy : 60.1655%, val_accuracy : 49.8871%
# Epoch [546], train_Loss : 0.0362, val_Loss : 0.0386,                train_accuracy : 58.6879%, val_accuracy : 52.3702%
# Epoch [551], train_Loss : 0.0361, val_Loss : 0.0390,                train_accuracy : 59.1608%, val_accuracy : 51.0158%
# Epoch [556], train_Loss : 0.0350, val_Loss : 0.0395,                train_accuracy : 62.6478%, val_accuracy : 49.2099%
# Epoch [561], train_Loss : 0.0358, val_Loss : 0.0394,                train_accuracy : 59.9291%, val_accuracy : 49.6614%
# Epoch [566], train_Loss : 0.0349, val_Loss : 0.0377,                train_accuracy : 63.0024%, val_accuracy : 55.0790%
# Epoch [571], train_Loss : 0.0351, val_Loss : 0.0380,                train_accuracy : 62.4114%, val_accuracy : 53.9503%
# Epoch [576], train_Loss : 0.0348, val_Loss : 0.0382,                train_accuracy : 63.1797%, val_accuracy : 53.4989%
# Epoch [581], train_Loss : 0.0361, val_Loss : 0.0385,                train_accuracy : 59.2199%, val_accuracy : 52.5959%
# Epoch [586], train_Loss : 0.0353, val_Loss : 0.0387,                train_accuracy : 61.4657%, val_accuracy : 51.9187%
# Epoch [591], train_Loss : 0.0343, val_Loss : 0.0384,                train_accuracy : 64.8345%, val_accuracy : 52.8217%
# Epoch [596], train_Loss : 0.0377, val_Loss : 0.0381,                train_accuracy : 53.9007%, val_accuracy : 53.7246%
# Epoch [601], train_Loss : 0.0346, val_Loss : 0.0377,                train_accuracy : 63.7707%, val_accuracy : 54.8533%
# Epoch [606], train_Loss : 0.0354, val_Loss : 0.0386,                train_accuracy : 61.3475%, val_accuracy : 52.1445%
# Epoch [611], train_Loss : 0.0364, val_Loss : 0.0382,                train_accuracy : 58.1560%, val_accuracy : 53.4989%
# Epoch [616], train_Loss : 0.0353, val_Loss : 0.0381,                train_accuracy : 61.5839%, val_accuracy : 53.7246%
# Epoch [621], train_Loss : 0.0362, val_Loss : 0.0390,                train_accuracy : 58.6879%, val_accuracy : 51.0158%
# Epoch [626], train_Loss : 0.0358, val_Loss : 0.0382,                train_accuracy : 60.1655%, val_accuracy : 53.2731%
# Epoch [631], train_Loss : 0.0357, val_Loss : 0.0383,                train_accuracy : 60.4019%, val_accuracy : 52.8217%
# Epoch [636], train_Loss : 0.0358, val_Loss : 0.0393,                train_accuracy : 60.2246%, val_accuracy : 49.8871%
# Epoch [641], train_Loss : 0.0357, val_Loss : 0.0380,                train_accuracy : 60.5201%, val_accuracy : 54.1761%
# Epoch [646], train_Loss : 0.0352, val_Loss : 0.0376,                train_accuracy : 61.8203%, val_accuracy : 55.3047%
# Epoch [651], train_Loss : 0.0353, val_Loss : 0.0382,                train_accuracy : 61.6430%, val_accuracy : 53.2731%
# Epoch [656], train_Loss : 0.0353, val_Loss : 0.0382,                train_accuracy : 61.5839%, val_accuracy : 53.2731%
# Epoch [661], train_Loss : 0.0355, val_Loss : 0.0381,                train_accuracy : 61.1111%, val_accuracy : 53.7246%
# Epoch [666], train_Loss : 0.0366, val_Loss : 0.0404,                train_accuracy : 57.3877%, val_accuracy : 46.5011%
# Epoch [671], train_Loss : 0.0374, val_Loss : 0.0396,                train_accuracy : 55.0827%, val_accuracy : 49.2099%
# Epoch [676], train_Loss : 0.0353, val_Loss : 0.0385,                train_accuracy : 61.5248%, val_accuracy : 52.5959%
# Epoch [681], train_Loss : 0.0376, val_Loss : 0.0398,                train_accuracy : 54.3144%, val_accuracy : 48.3070%
# Epoch [686], train_Loss : 0.0354, val_Loss : 0.0380,                train_accuracy : 61.2293%, val_accuracy : 54.1761%
# Epoch [691], train_Loss : 0.0356, val_Loss : 0.0380,                train_accuracy : 60.6974%, val_accuracy : 53.9503%
# Epoch [696], train_Loss : 0.0365, val_Loss : 0.0382,                train_accuracy : 57.9196%, val_accuracy : 53.2731%
# Epoch [701], train_Loss : 0.0364, val_Loss : 0.0386,                train_accuracy : 58.3333%, val_accuracy : 52.3702%
# Epoch [706], train_Loss : 0.0361, val_Loss : 0.0378,                train_accuracy : 58.9835%, val_accuracy : 54.6275%
# Epoch [711], train_Loss : 0.0351, val_Loss : 0.0382,                train_accuracy : 62.3522%, val_accuracy : 53.2731%
# Epoch [716], train_Loss : 0.0356, val_Loss : 0.0381,                train_accuracy : 60.6974%, val_accuracy : 53.7246%
# Epoch [721], train_Loss : 0.0350, val_Loss : 0.0376,                train_accuracy : 62.5886%, val_accuracy : 55.5305%
# Epoch [726], train_Loss : 0.0362, val_Loss : 0.0379,                train_accuracy : 58.6879%, val_accuracy : 54.4018%
# Epoch [731], train_Loss : 0.0364, val_Loss : 0.0387,                train_accuracy : 58.1560%, val_accuracy : 51.9187%
# Epoch [736], train_Loss : 0.0365, val_Loss : 0.0388,                train_accuracy : 57.6832%, val_accuracy : 51.6930%
# Epoch [741], train_Loss : 0.0369, val_Loss : 0.0392,                train_accuracy : 56.5012%, val_accuracy : 50.3386%
# Epoch [746], train_Loss : 0.0377, val_Loss : 0.0395,                train_accuracy : 54.0189%, val_accuracy : 49.6614%
# Epoch [751], train_Loss : 0.0360, val_Loss : 0.0378,                train_accuracy : 59.5154%, val_accuracy : 54.6275%
# Epoch [756], train_Loss : 0.0379, val_Loss : 0.0393,                train_accuracy : 53.3688%, val_accuracy : 49.8871%
# Epoch [761], train_Loss : 0.0388, val_Loss : 0.0405,                train_accuracy : 50.6501%, val_accuracy : 46.5011%
# Epoch [766], train_Loss : 0.0397, val_Loss : 0.0412,                train_accuracy : 47.6950%, val_accuracy : 44.0181%
# Epoch [771], train_Loss : 0.0372, val_Loss : 0.0390,                train_accuracy : 55.4374%, val_accuracy : 50.7901%
# Epoch [776], train_Loss : 0.0359, val_Loss : 0.0387,                train_accuracy : 59.8109%, val_accuracy : 51.9187%
# Epoch [781], train_Loss : 0.0365, val_Loss : 0.0383,                train_accuracy : 57.8605%, val_accuracy : 53.2731%
# Epoch [786], train_Loss : 0.0361, val_Loss : 0.0394,                train_accuracy : 59.2199%, val_accuracy : 49.8871%
# Epoch [791], train_Loss : 0.0358, val_Loss : 0.0384,                train_accuracy : 60.1064%, val_accuracy : 52.8217%
# Epoch [796], train_Loss : 0.0361, val_Loss : 0.0382,                train_accuracy : 59.1017%, val_accuracy : 53.4989%
# Epoch [801], train_Loss : 0.0358, val_Loss : 0.0384,                train_accuracy : 60.1655%, val_accuracy : 52.8217%
# Epoch [806], train_Loss : 0.0361, val_Loss : 0.0405,                train_accuracy : 58.9243%, val_accuracy : 46.2754%
# Epoch [811], train_Loss : 0.0363, val_Loss : 0.0388,                train_accuracy : 58.4515%, val_accuracy : 51.6930%
# Epoch [816], train_Loss : 0.0365, val_Loss : 0.0387,                train_accuracy : 57.8605%, val_accuracy : 51.6930%
# Epoch [821], train_Loss : 0.0365, val_Loss : 0.0398,                train_accuracy : 57.9196%, val_accuracy : 48.7585%
# Epoch [826], train_Loss : 0.0364, val_Loss : 0.0388,                train_accuracy : 58.0378%, val_accuracy : 51.4673%
# Epoch [831], train_Loss : 0.0369, val_Loss : 0.0395,                train_accuracy : 56.4421%, val_accuracy : 49.2099%
# Epoch [836], train_Loss : 0.0366, val_Loss : 0.0393,                train_accuracy : 57.5059%, val_accuracy : 50.1129%
# Epoch [841], train_Loss : 0.0374, val_Loss : 0.0411,                train_accuracy : 54.9645%, val_accuracy : 44.4695%
# Epoch [846], train_Loss : 0.0370, val_Loss : 0.0401,                train_accuracy : 56.2057%, val_accuracy : 47.6298%
# Epoch [851], train_Loss : 0.0373, val_Loss : 0.0397,                train_accuracy : 55.1418%, val_accuracy : 48.7585%
# Epoch [856], train_Loss : 0.0363, val_Loss : 0.0394,                train_accuracy : 58.3924%, val_accuracy : 49.6614%
# Epoch [861], train_Loss : 0.0365, val_Loss : 0.0393,                train_accuracy : 57.7423%, val_accuracy : 49.8871%
# Epoch [866], train_Loss : 0.0369, val_Loss : 0.0391,                train_accuracy : 56.3830%, val_accuracy : 50.5643%
# Epoch [871], train_Loss : 0.0366, val_Loss : 0.0392,                train_accuracy : 57.5059%, val_accuracy : 50.3386%
# Epoch [876], train_Loss : 0.0364, val_Loss : 0.0384,                train_accuracy : 58.2742%, val_accuracy : 52.5959%
# Epoch [881], train_Loss : 0.0352, val_Loss : 0.0377,                train_accuracy : 61.8203%, val_accuracy : 55.0790%
# Epoch [886], train_Loss : 0.0361, val_Loss : 0.0377,                train_accuracy : 59.1017%, val_accuracy : 55.0790%
# Epoch [891], train_Loss : 0.0363, val_Loss : 0.0386,                train_accuracy : 58.3924%, val_accuracy : 52.1445%
# Epoch [896], train_Loss : 0.0371, val_Loss : 0.0371,                train_accuracy : 55.9693%, val_accuracy : 57.1106%
# Epoch [901], train_Loss : 0.0376, val_Loss : 0.0382,                train_accuracy : 54.1962%, val_accuracy : 53.4989%
# Epoch [906], train_Loss : 0.0364, val_Loss : 0.0372,                train_accuracy : 58.0969%, val_accuracy : 56.4334%
# Epoch [911], train_Loss : 0.0357, val_Loss : 0.0374,                train_accuracy : 60.2837%, val_accuracy : 56.2077%
# Epoch [916], train_Loss : 0.0372, val_Loss : 0.0400,                train_accuracy : 55.6147%, val_accuracy : 47.8555%
# Epoch [921], train_Loss : 0.0363, val_Loss : 0.0391,                train_accuracy : 58.3333%, val_accuracy : 50.7901%
# Epoch [926], train_Loss : 0.0360, val_Loss : 0.0389,                train_accuracy : 59.5154%, val_accuracy : 51.2415%
# Epoch [931], train_Loss : 0.0360, val_Loss : 0.0379,                train_accuracy : 59.5154%, val_accuracy : 54.6275%
# Epoch [936], train_Loss : 0.0357, val_Loss : 0.0388,                train_accuracy : 60.5201%, val_accuracy : 51.4673%
# Epoch [941], train_Loss : 0.0363, val_Loss : 0.0391,                train_accuracy : 58.3924%, val_accuracy : 50.5643%
# Epoch [946], train_Loss : 0.0391, val_Loss : 0.0390,                train_accuracy : 49.3499%, val_accuracy : 50.7901%
# Epoch [951], train_Loss : 0.0364, val_Loss : 0.0397,                train_accuracy : 58.2742%, val_accuracy : 48.7585%
# Epoch [956], train_Loss : 0.0369, val_Loss : 0.0394,                train_accuracy : 56.6785%, val_accuracy : 49.8871%
# Epoch [961], train_Loss : 0.0381, val_Loss : 0.0404,                train_accuracy : 52.6005%, val_accuracy : 46.7269%
# Epoch [966], train_Loss : 0.0378, val_Loss : 0.0398,                train_accuracy : 53.8416%, val_accuracy : 48.5327%
# Epoch [971], train_Loss : 0.0370, val_Loss : 0.0385,                train_accuracy : 56.2057%, val_accuracy : 52.5959%
# Epoch [976], train_Loss : 0.0383, val_Loss : 0.0406,                train_accuracy : 52.1868%, val_accuracy : 45.8239%
# Epoch [981], train_Loss : 0.0384, val_Loss : 0.0401,                train_accuracy : 51.6548%, val_accuracy : 47.4041%
# Epoch [986], train_Loss : 0.0375, val_Loss : 0.0380,                train_accuracy : 54.7281%, val_accuracy : 54.1761%
# Epoch [991], train_Loss : 0.0366, val_Loss : 0.0389,                train_accuracy : 57.5650%, val_accuracy : 51.2415%
# Epoch [996], train_Loss : 0.0369, val_Loss : 0.0410,                train_accuracy : 56.6194%, val_accuracy : 44.6953%

# %%
model = CNN().to(device)
model.load_state_dict(torch.load('CNN_model.pt'))
model.eval()
test_loss, test_acc = predict(model, optimizer, criterion, test_dataloader)

print(f'Test_Loss : {test_loss:.4f},Test_Accuracy : {100*test_acc:.4f}%')
# Out:
# Test_Loss : 0.0362,Test_Accuracy : 59.8194%

# %%
num_epochs=1000
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)
ax.plot(range(num_epochs), train_loss_list, c='b', label='train loss')
ax.plot(range(num_epochs), test_loss_list, c='r', label='val loss')
ax.set_xlabel('epoch', fontsize='20')
ax.set_ylabel('loss', fontsize='20')
ax.set_title('train and val loss', fontsize='20')
ax.grid()
ax.legend(fontsize='25')
plt.show()

# %%
from torchsummary import summary
model = CNN()
summary(model, (1, 22, 1000))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 22, 1000]             320
#             Conv2d-2         [-1, 32, 22, 1000]           9,248
#          MaxPool2d-3          [-1, 32, 11, 500]               0
#        BatchNorm2d-4          [-1, 32, 11, 500]              64
#                ELU-5          [-1, 32, 11, 500]               0
#            Dropout-6          [-1, 32, 11, 500]               0
#             Conv2d-7          [-1, 16, 11, 500]           4,624
#             Conv2d-8          [-1, 16, 11, 500]           2,320
#          MaxPool2d-9          [-1, 16, 11, 250]               0
#       BatchNorm2d-10          [-1, 16, 11, 250]              32
#               ELU-11          [-1, 16, 11, 250]               0
#           Dropout-12          [-1, 16, 11, 250]               0
#            Conv2d-13           [-1, 8, 11, 250]           3,208
#            Conv2d-14           [-1, 8, 11, 250]             584
#         MaxPool2d-15           [-1, 8, 11, 125]               0
#       BatchNorm2d-16           [-1, 8, 11, 125]              16
#               ELU-17           [-1, 8, 11, 125]               0
#           Dropout-18           [-1, 8, 11, 125]               0
#            Conv2d-19           [-1, 4, 11, 125]             804
#            Conv2d-20           [-1, 4, 11, 125]             148
#         AvgPool2d-21            [-1, 4, 11, 25]               0
#       BatchNorm2d-22            [-1, 4, 11, 25]               8
#               ELU-23            [-1, 4, 11, 25]               0
#           Dropout-24            [-1, 4, 11, 25]               0
#            Linear-25                  [-1, 256]         281,856
#            Linear-26                   [-1, 64]          16,448
#            Linear-27                   [-1, 16]           1,040
#            Linear-28                    [-1, 4]              68
#           Softmax-29                    [-1, 4]               0
# ================================================================
# Total params: 320,788
# Trainable params: 320,788
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.08
# Forward/backward pass size (MB): 19.59
# Params size (MB): 1.22
# Estimated Total Size (MB): 20.90
# ----------------------------------------------------------------
