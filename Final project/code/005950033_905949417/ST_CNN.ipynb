# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import scipy

# %%
device = "mps" if torch.backends.mps.is_available() else "cpu"
device = torch.device(device)
print('Using {} device'.format(device))
#device = torch.device("cpu")
# Out:
# Using mps device

# %%
X_test = np.load("X_test.npy")
# X_test = scipy.stats.zscore(X_test, axis=1)
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
# X_train_valid = scipy.stats.zscore(X_train_valid, axis=1)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")
y_test -= 769
y_train_valid -= 769

# %%
idx_val = np.random.choice(2115, 423, replace=False)
idx_tra = np.array(list(set(range(2115)).difference(set(idx_val))))
X_train, X_val = X_train_valid[idx_tra], X_train_valid[idx_val] 
y_train, y_val = y_train_valid[idx_tra], y_train_valid[idx_val]

# %% [markdown]
# ### Shape of data

# %%
print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %% [markdown]
# # To torch.tensor

# %%
X_train = torch.from_numpy(X_train).float()
X_train = X_train[:,None,:,:]
y_train = torch.from_numpy(y_train).long()
X_val = torch.from_numpy(X_val).float()
X_val = X_val[:,None,:,:]
y_val = torch.from_numpy(y_val).long()
X_test = torch.from_numpy(X_test).float()
X_test = X_test[:,None,:,:]
y_test = torch.from_numpy(y_test).long()

# %% [markdown]
# # Dataset Class

# %%
train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
val_dataset = torch.utils.data.TensorDataset(X_val, y_val)
test_dataset = torch.utils.data.TensorDataset(X_test, y_test)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# # Network

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        #nn.Conv2d(in_channels, out_channels, kernel_size)
        #input:(C,H,W)=(1,22,1000)
        
        self.conv1 = nn.Conv2d(1, 32, (1,64), padding='same') #(32,22,1000)
        self.bn1   = nn.BatchNorm2d(32) #(32,22,500)
        
        self.conv2 = nn.Conv2d(32, 64, (22,1)) #(64,1,1000)
        self.bn2   = nn.BatchNorm2d(64) #(64,1,1000) 
        #--->ELU()
        self.pool1 = nn.AvgPool2d([1, 5], stride=[1, 5], padding=0) #(64,1,200)
        
        self.conv3 = nn.Conv2d(64, 64, (1,16), padding='same') #(64,1,250)
        self.conv4 = nn.Conv2d(64, 64, (1,1), padding='same') #(64,1,250)
        self.bn3   = nn.BatchNorm2d(64) #(64,1,250)
        #--->ELU()
        self.pool2 = nn.AvgPool2d([1, 5], stride=[1, 5], padding=0) #(64,1,40)
        
        self.fc1 = nn.Linear(64*1*40,256)
        self.fc2 = nn.Linear(256,4)
        
        self.sm = nn.Softmax(dim=1)
        
        #non-linear
        self.nonlinear = nn.ELU(True)
        #Dropout
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        
        x = self.bn1(self.conv1(x))
        
        x = self.nonlinear(self.bn2(self.conv2(x)))
        x = self.pool1(x)
        x = self.dropout(x)
        
        x = self.nonlinear(self.bn3(self.conv4(self.conv3(x))))
        x = self.pool2(x)
        x = self.dropout(x)
        
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.fc2(x)
        # x = self.sm(x)
        return x

# %%
def train_epoch(model, optimizer, criterion, dataloader):
    train_loss = 0
    train_acc = 0
    model.train()
    for i, (inp, labels) in enumerate(dataloader):
        inp, labels = inp.to(device), labels.to(device)
        optimizer.zero_grad()
        outp = model(inp)
        outp_pred = torch.max(outp,axis=1).indices
        train_acc += torch.sum(outp_pred == labels)
        loss = criterion(outp, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss = train_loss / len(train_dataloader.dataset)
    train_acc = train_acc/ len(train_dataloader.dataset)
    return train_loss, train_acc

# %%
def predict(model, optimizer, criterion, dataloader, pred_loader=test_dataloader):
    test_loss = 0
    test_acc = 0
    best_acc = 0
    model.eval()
    with torch.no_grad():
        for i, (inp, labels) in enumerate(pred_loader):
            inp, labels = inp.to(device), labels.to(device)
            outp = model(inp)
            outp_pred = torch.max(outp,axis=1).indices
            test_acc += torch.sum(outp_pred == labels)
            loss = criterion(outp, labels)
            test_loss += loss.item()
        test_loss = test_loss / len(pred_loader.dataset)
        test_acc = test_acc / len(pred_loader.dataset)
    return test_loss, test_acc

# %%
acc_device = torch.device('cpu')
def run(num_epochs, optimizer, criterion, pred_loader=test_dataloader):
    train_loss_list = []
    test_loss_list = []
    train_acc_list = []
    test_acc_list = []
    best_acc = 0
    for epoch in range(num_epochs):
        train_loss, train_acc = train_epoch(model, optimizer, criterion, train_dataloader)
        test_loss, test_acc = predict(model, optimizer, criterion, pred_loader)
        # if epoch % 5 == 0:
        #     print(f'Epoch [{epoch+1}], train_Loss : {train_loss:.4f}, val_Loss : {test_loss:.4f},\
        #         train_accuracy : {100*train_acc:.4f}%, val_accuracy : {100*test_acc:.4f}%')
        print(f'Epoch [{epoch+1}], train_Loss : {train_loss:.4f}, val_Loss : {test_loss:.4f},\
                train_accuracy : {100*train_acc:.4f}%, val_accuracy : {100*test_acc:.4f}%')
        train_loss_list.append(train_loss)
        test_loss_list.append(test_loss)
        train_acc_list.append(train_acc.to(acc_device))
        test_acc_list.append(test_acc.to(acc_device))

        if test_acc > best_acc and pred_loader != test_dataloader:
            torch.save(model.state_dict(), 'CNN_2nd_update.pt')
            best_acc = test_acc
    return train_loss_list, test_loss_list, train_acc_list, test_acc_list

# %%
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
train_loss_list, test_loss_list, train_acc_list, test_acc_list = run(200, optimizer, criterion, val_dataloader)
# Out:
# /Users/hodaka/opt/anaconda3/envs/torch-gpu/lib/python3.8/site-packages/torch/nn/modules/conv.py:459: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1678522338528/work/aten/src/ATen/native/Convolution.cpp:1004.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch [1], train_Loss : 0.0469, val_Loss : 0.0418,                train_accuracy : 33.9835%, val_accuracy : 33.8600%
# Epoch [2], train_Loss : 0.0387, val_Loss : 0.0371,                train_accuracy : 44.2080%, val_accuracy : 49.8871%
# Epoch [3], train_Loss : 0.0353, val_Loss : 0.0362,                train_accuracy : 50.7683%, val_accuracy : 52.8217%
# Epoch [4], train_Loss : 0.0342, val_Loss : 0.0365,                train_accuracy : 54.1371%, val_accuracy : 48.0813%
# Epoch [5], train_Loss : 0.0328, val_Loss : 0.0351,                train_accuracy : 56.2648%, val_accuracy : 49.8871%
# Epoch [6], train_Loss : 0.0314, val_Loss : 0.0344,                train_accuracy : 58.9243%, val_accuracy : 51.2415%
# Epoch [7], train_Loss : 0.0305, val_Loss : 0.0334,                train_accuracy : 59.4563%, val_accuracy : 57.3363%
# Epoch [8], train_Loss : 0.0293, val_Loss : 0.0341,                train_accuracy : 61.7021%, val_accuracy : 55.3047%
# Epoch [9], train_Loss : 0.0281, val_Loss : 0.0329,                train_accuracy : 64.0071%, val_accuracy : 55.3047%
# Epoch [10], train_Loss : 0.0269, val_Loss : 0.0332,                train_accuracy : 66.0165%, val_accuracy : 59.1422%
# Epoch [11], train_Loss : 0.0256, val_Loss : 0.0322,                train_accuracy : 66.0757%, val_accuracy : 58.2393%
# Epoch [12], train_Loss : 0.0264, val_Loss : 0.0325,                train_accuracy : 67.3168%, val_accuracy : 56.8849%
# Epoch [13], train_Loss : 0.0255, val_Loss : 0.0309,                train_accuracy : 67.1395%, val_accuracy : 58.9165%
# Epoch [14], train_Loss : 0.0235, val_Loss : 0.0316,                train_accuracy : 69.6217%, val_accuracy : 61.3995%
# Epoch [15], train_Loss : 0.0232, val_Loss : 0.0307,                train_accuracy : 70.6265%, val_accuracy : 61.8510%
# Epoch [16], train_Loss : 0.0240, val_Loss : 0.0311,                train_accuracy : 69.0307%, val_accuracy : 61.6253%
# Epoch [17], train_Loss : 0.0217, val_Loss : 0.0316,                train_accuracy : 73.2270%, val_accuracy : 59.3680%
# Epoch [18], train_Loss : 0.0218, val_Loss : 0.0320,                train_accuracy : 72.3404%, val_accuracy : 60.9481%
# Epoch [19], train_Loss : 0.0209, val_Loss : 0.0324,                train_accuracy : 74.4681%, val_accuracy : 59.3680%
# Epoch [20], train_Loss : 0.0209, val_Loss : 0.0302,                train_accuracy : 72.8723%, val_accuracy : 62.0768%
# Epoch [21], train_Loss : 0.0205, val_Loss : 0.0297,                train_accuracy : 74.1726%, val_accuracy : 62.3025%
# Epoch [22], train_Loss : 0.0195, val_Loss : 0.0306,                train_accuracy : 74.4681%, val_accuracy : 62.7540%
# Epoch [23], train_Loss : 0.0188, val_Loss : 0.0287,                train_accuracy : 77.0095%, val_accuracy : 67.0429%
# Epoch [24], train_Loss : 0.0185, val_Loss : 0.0304,                train_accuracy : 76.4184%, val_accuracy : 66.5914%
# Epoch [25], train_Loss : 0.0182, val_Loss : 0.0294,                train_accuracy : 77.8960%, val_accuracy : 65.2370%
# Epoch [26], train_Loss : 0.0172, val_Loss : 0.0300,                train_accuracy : 79.6690%, val_accuracy : 65.2370%
# Epoch [27], train_Loss : 0.0170, val_Loss : 0.0308,                train_accuracy : 78.3688%, val_accuracy : 64.7856%
# Epoch [28], train_Loss : 0.0173, val_Loss : 0.0309,                train_accuracy : 79.1962%, val_accuracy : 65.9142%
# Epoch [29], train_Loss : 0.0172, val_Loss : 0.0304,                train_accuracy : 77.8960%, val_accuracy : 64.5598%
# Epoch [30], train_Loss : 0.0156, val_Loss : 0.0302,                train_accuracy : 79.7281%, val_accuracy : 65.6885%
# Epoch [31], train_Loss : 0.0166, val_Loss : 0.0307,                train_accuracy : 79.6690%, val_accuracy : 66.5914%
# Epoch [32], train_Loss : 0.0153, val_Loss : 0.0299,                train_accuracy : 81.0875%, val_accuracy : 66.8172%
# Epoch [33], train_Loss : 0.0155, val_Loss : 0.0295,                train_accuracy : 80.5556%, val_accuracy : 65.9142%
# Epoch [34], train_Loss : 0.0141, val_Loss : 0.0322,                train_accuracy : 83.2151%, val_accuracy : 64.5598%
# Epoch [35], train_Loss : 0.0147, val_Loss : 0.0292,                train_accuracy : 82.3877%, val_accuracy : 67.4944%
# Epoch [36], train_Loss : 0.0149, val_Loss : 0.0289,                train_accuracy : 81.2057%, val_accuracy : 68.1716%
# Epoch [37], train_Loss : 0.0132, val_Loss : 0.0300,                train_accuracy : 83.4515%, val_accuracy : 67.7201%
# Epoch [38], train_Loss : 0.0141, val_Loss : 0.0324,                train_accuracy : 82.2695%, val_accuracy : 65.4628%
# Epoch [39], train_Loss : 0.0128, val_Loss : 0.0307,                train_accuracy : 84.2199%, val_accuracy : 66.5914%
# Epoch [40], train_Loss : 0.0138, val_Loss : 0.0348,                train_accuracy : 83.0378%, val_accuracy : 66.8172%
# Epoch [41], train_Loss : 0.0134, val_Loss : 0.0296,                train_accuracy : 83.2151%, val_accuracy : 70.2032%
# Epoch [42], train_Loss : 0.0128, val_Loss : 0.0341,                train_accuracy : 84.8700%, val_accuracy : 63.4312%
# Epoch [43], train_Loss : 0.0135, val_Loss : 0.0296,                train_accuracy : 83.1560%, val_accuracy : 65.4628%
# Epoch [44], train_Loss : 0.0117, val_Loss : 0.0329,                train_accuracy : 85.9929%, val_accuracy : 67.4944%
# Epoch [45], train_Loss : 0.0122, val_Loss : 0.0312,                train_accuracy : 85.1655%, val_accuracy : 66.3657%
# Epoch [46], train_Loss : 0.0127, val_Loss : 0.0308,                train_accuracy : 84.1608%, val_accuracy : 66.1400%
# Epoch [47], train_Loss : 0.0120, val_Loss : 0.0314,                train_accuracy : 85.9338%, val_accuracy : 67.4944%
# Epoch [48], train_Loss : 0.0119, val_Loss : 0.0323,                train_accuracy : 85.4610%, val_accuracy : 66.1400%
# Epoch [49], train_Loss : 0.0119, val_Loss : 0.0320,                train_accuracy : 85.6974%, val_accuracy : 67.4944%
# Epoch [50], train_Loss : 0.0117, val_Loss : 0.0313,                train_accuracy : 85.9338%, val_accuracy : 69.3002%
# Epoch [51], train_Loss : 0.0108, val_Loss : 0.0333,                train_accuracy : 85.6974%, val_accuracy : 67.0429%
# Epoch [52], train_Loss : 0.0113, val_Loss : 0.0322,                train_accuracy : 86.9385%, val_accuracy : 69.5260%
# Epoch [53], train_Loss : 0.0112, val_Loss : 0.0318,                train_accuracy : 85.9929%, val_accuracy : 67.9458%
# Epoch [54], train_Loss : 0.0108, val_Loss : 0.0333,                train_accuracy : 86.8203%, val_accuracy : 67.2686%
# Epoch [55], train_Loss : 0.0101, val_Loss : 0.0343,                train_accuracy : 87.1749%, val_accuracy : 67.4944%
# Epoch [56], train_Loss : 0.0110, val_Loss : 0.0332,                train_accuracy : 86.9976%, val_accuracy : 67.9458%
# Epoch [57], train_Loss : 0.0110, val_Loss : 0.0312,                train_accuracy : 85.8156%, val_accuracy : 68.1716%
# Epoch [58], train_Loss : 0.0103, val_Loss : 0.0315,                train_accuracy : 87.2931%, val_accuracy : 68.8488%
# Epoch [59], train_Loss : 0.0105, val_Loss : 0.0324,                train_accuracy : 87.5887%, val_accuracy : 68.1716%
# Epoch [60], train_Loss : 0.0100, val_Loss : 0.0322,                train_accuracy : 87.5887%, val_accuracy : 70.4289%
# Epoch [61], train_Loss : 0.0105, val_Loss : 0.0346,                train_accuracy : 86.5248%, val_accuracy : 67.4944%
# Epoch [62], train_Loss : 0.0097, val_Loss : 0.0331,                train_accuracy : 88.4161%, val_accuracy : 66.3657%
# Epoch [63], train_Loss : 0.0104, val_Loss : 0.0313,                train_accuracy : 87.1749%, val_accuracy : 67.4944%
# Epoch [64], train_Loss : 0.0099, val_Loss : 0.0330,                train_accuracy : 88.1206%, val_accuracy : 67.4944%
# Epoch [65], train_Loss : 0.0097, val_Loss : 0.0333,                train_accuracy : 87.8842%, val_accuracy : 66.5914%
# Epoch [66], train_Loss : 0.0094, val_Loss : 0.0330,                train_accuracy : 88.8298%, val_accuracy : 68.8488%
# Epoch [67], train_Loss : 0.0098, val_Loss : 0.0370,                train_accuracy : 88.2388%, val_accuracy : 66.8172%
# Epoch [68], train_Loss : 0.0093, val_Loss : 0.0339,                train_accuracy : 88.8298%, val_accuracy : 66.1400%
# Epoch [69], train_Loss : 0.0089, val_Loss : 0.0360,                train_accuracy : 89.0071%, val_accuracy : 67.7201%
# Epoch [70], train_Loss : 0.0088, val_Loss : 0.0344,                train_accuracy : 89.0071%, val_accuracy : 66.8172%
# Epoch [71], train_Loss : 0.0085, val_Loss : 0.0373,                train_accuracy : 89.7163%, val_accuracy : 66.8172%
# Epoch [72], train_Loss : 0.0087, val_Loss : 0.0359,                train_accuracy : 89.3617%, val_accuracy : 67.9458%
# Epoch [73], train_Loss : 0.0091, val_Loss : 0.0346,                train_accuracy : 89.1253%, val_accuracy : 67.4944%
# Epoch [74], train_Loss : 0.0092, val_Loss : 0.0351,                train_accuracy : 88.4752%, val_accuracy : 66.5914%
# Epoch [75], train_Loss : 0.0093, val_Loss : 0.0344,                train_accuracy : 89.1844%, val_accuracy : 67.9458%
# Epoch [76], train_Loss : 0.0103, val_Loss : 0.0338,                train_accuracy : 87.3522%, val_accuracy : 67.0429%
# Epoch [77], train_Loss : 0.0093, val_Loss : 0.0335,                train_accuracy : 89.4208%, val_accuracy : 65.9142%
# Epoch [78], train_Loss : 0.0084, val_Loss : 0.0348,                train_accuracy : 89.8345%, val_accuracy : 67.4944%
# Epoch [79], train_Loss : 0.0090, val_Loss : 0.0395,                train_accuracy : 89.3617%, val_accuracy : 65.6885%
# Epoch [80], train_Loss : 0.0092, val_Loss : 0.0338,                train_accuracy : 89.1844%, val_accuracy : 69.3002%
# Epoch [81], train_Loss : 0.0074, val_Loss : 0.0394,                train_accuracy : 90.8392%, val_accuracy : 66.3657%
# Epoch [82], train_Loss : 0.0087, val_Loss : 0.0347,                train_accuracy : 88.4752%, val_accuracy : 67.2686%
# Epoch [83], train_Loss : 0.0087, val_Loss : 0.0358,                train_accuracy : 89.7754%, val_accuracy : 66.3657%
# Epoch [84], train_Loss : 0.0080, val_Loss : 0.0376,                train_accuracy : 90.6028%, val_accuracy : 66.3657%
# Epoch [85], train_Loss : 0.0080, val_Loss : 0.0356,                train_accuracy : 91.0165%, val_accuracy : 66.3657%
# Epoch [86], train_Loss : 0.0086, val_Loss : 0.0351,                train_accuracy : 88.6525%, val_accuracy : 67.4944%
# Epoch [87], train_Loss : 0.0077, val_Loss : 0.0371,                train_accuracy : 90.0709%, val_accuracy : 65.2370%
# Epoch [88], train_Loss : 0.0087, val_Loss : 0.0374,                train_accuracy : 89.6572%, val_accuracy : 66.5914%
# Epoch [89], train_Loss : 0.0088, val_Loss : 0.0344,                train_accuracy : 88.7116%, val_accuracy : 67.4944%
# Epoch [90], train_Loss : 0.0082, val_Loss : 0.0354,                train_accuracy : 90.8983%, val_accuracy : 66.8172%
# Epoch [91], train_Loss : 0.0081, val_Loss : 0.0366,                train_accuracy : 90.8392%, val_accuracy : 65.0113%
# Epoch [92], train_Loss : 0.0076, val_Loss : 0.0378,                train_accuracy : 90.6619%, val_accuracy : 65.2370%
# Epoch [93], train_Loss : 0.0075, val_Loss : 0.0377,                train_accuracy : 90.5437%, val_accuracy : 66.3657%
# Epoch [94], train_Loss : 0.0072, val_Loss : 0.0361,                train_accuracy : 91.0165%, val_accuracy : 68.3973%
# Epoch [95], train_Loss : 0.0072, val_Loss : 0.0354,                train_accuracy : 90.8392%, val_accuracy : 67.4944%
# Epoch [96], train_Loss : 0.0090, val_Loss : 0.0341,                train_accuracy : 89.3026%, val_accuracy : 66.5914%
# Epoch [97], train_Loss : 0.0073, val_Loss : 0.0369,                train_accuracy : 91.6076%, val_accuracy : 64.7856%
# Epoch [98], train_Loss : 0.0073, val_Loss : 0.0362,                train_accuracy : 91.1939%, val_accuracy : 68.6230%
# Epoch [99], train_Loss : 0.0072, val_Loss : 0.0360,                train_accuracy : 91.4894%, val_accuracy : 69.5260%
# Epoch [100], train_Loss : 0.0074, val_Loss : 0.0363,                train_accuracy : 91.7258%, val_accuracy : 68.6230%
# Epoch [101], train_Loss : 0.0074, val_Loss : 0.0367,                train_accuracy : 90.8983%, val_accuracy : 65.6885%
# Epoch [102], train_Loss : 0.0077, val_Loss : 0.0379,                train_accuracy : 90.6028%, val_accuracy : 67.7201%
# Epoch [103], train_Loss : 0.0084, val_Loss : 0.0360,                train_accuracy : 90.8983%, val_accuracy : 68.6230%
# Epoch [104], train_Loss : 0.0076, val_Loss : 0.0366,                train_accuracy : 90.6028%, val_accuracy : 69.0745%
# Epoch [105], train_Loss : 0.0077, val_Loss : 0.0366,                train_accuracy : 90.7210%, val_accuracy : 67.2686%
# Epoch [106], train_Loss : 0.0065, val_Loss : 0.0350,                train_accuracy : 92.6123%, val_accuracy : 69.5260%
# Epoch [107], train_Loss : 0.0066, val_Loss : 0.0377,                train_accuracy : 92.0804%, val_accuracy : 68.1716%
# Epoch [108], train_Loss : 0.0072, val_Loss : 0.0376,                train_accuracy : 91.7849%, val_accuracy : 66.3657%
# Epoch [109], train_Loss : 0.0070, val_Loss : 0.0348,                train_accuracy : 91.9031%, val_accuracy : 67.0429%
# Epoch [110], train_Loss : 0.0063, val_Loss : 0.0394,                train_accuracy : 92.0804%, val_accuracy : 68.3973%
# Epoch [111], train_Loss : 0.0063, val_Loss : 0.0384,                train_accuracy : 92.5532%, val_accuracy : 67.4944%
# Epoch [112], train_Loss : 0.0069, val_Loss : 0.0366,                train_accuracy : 91.7849%, val_accuracy : 68.8488%
# Epoch [113], train_Loss : 0.0067, val_Loss : 0.0379,                train_accuracy : 92.3759%, val_accuracy : 68.8488%
# Epoch [114], train_Loss : 0.0066, val_Loss : 0.0395,                train_accuracy : 91.6667%, val_accuracy : 67.9458%
# Epoch [115], train_Loss : 0.0067, val_Loss : 0.0356,                train_accuracy : 92.3759%, val_accuracy : 70.6546%
# Epoch [116], train_Loss : 0.0054, val_Loss : 0.0397,                train_accuracy : 94.0307%, val_accuracy : 68.3973%
# Epoch [117], train_Loss : 0.0056, val_Loss : 0.0414,                train_accuracy : 94.0898%, val_accuracy : 68.1716%
# Epoch [118], train_Loss : 0.0068, val_Loss : 0.0389,                train_accuracy : 91.3712%, val_accuracy : 67.4944%
# Epoch [119], train_Loss : 0.0067, val_Loss : 0.0379,                train_accuracy : 91.5485%, val_accuracy : 69.0745%
# Epoch [120], train_Loss : 0.0073, val_Loss : 0.0362,                train_accuracy : 90.9574%, val_accuracy : 70.4289%
# Epoch [121], train_Loss : 0.0062, val_Loss : 0.0367,                train_accuracy : 92.3168%, val_accuracy : 70.2032%
# Epoch [122], train_Loss : 0.0068, val_Loss : 0.0385,                train_accuracy : 91.7258%, val_accuracy : 68.6230%
# Epoch [123], train_Loss : 0.0065, val_Loss : 0.0372,                train_accuracy : 92.3759%, val_accuracy : 69.5260%
# Epoch [124], train_Loss : 0.0066, val_Loss : 0.0375,                train_accuracy : 92.1986%, val_accuracy : 69.9774%
# Epoch [125], train_Loss : 0.0065, val_Loss : 0.0381,                train_accuracy : 92.1986%, val_accuracy : 68.1716%
# Epoch [126], train_Loss : 0.0067, val_Loss : 0.0375,                train_accuracy : 92.0213%, val_accuracy : 68.3973%
# Epoch [127], train_Loss : 0.0070, val_Loss : 0.0395,                train_accuracy : 91.0757%, val_accuracy : 68.1716%
# Epoch [128], train_Loss : 0.0071, val_Loss : 0.0373,                train_accuracy : 91.4894%, val_accuracy : 68.8488%
# Epoch [129], train_Loss : 0.0065, val_Loss : 0.0378,                train_accuracy : 92.2577%, val_accuracy : 68.3973%
# Epoch [130], train_Loss : 0.0067, val_Loss : 0.0355,                train_accuracy : 92.1986%, val_accuracy : 67.9458%
# Epoch [131], train_Loss : 0.0042, val_Loss : 0.0383,                train_accuracy : 95.2128%, val_accuracy : 69.3002%
# Epoch [132], train_Loss : 0.0061, val_Loss : 0.0414,                train_accuracy : 92.6123%, val_accuracy : 69.0745%
# Epoch [133], train_Loss : 0.0071, val_Loss : 0.0364,                train_accuracy : 91.1939%, val_accuracy : 69.5260%
# Epoch [134], train_Loss : 0.0067, val_Loss : 0.0378,                train_accuracy : 92.2577%, val_accuracy : 67.9458%
# Epoch [135], train_Loss : 0.0061, val_Loss : 0.0400,                train_accuracy : 92.3759%, val_accuracy : 67.2686%
# Epoch [136], train_Loss : 0.0067, val_Loss : 0.0365,                train_accuracy : 91.9031%, val_accuracy : 68.8488%
# Epoch [137], train_Loss : 0.0070, val_Loss : 0.0372,                train_accuracy : 91.6076%, val_accuracy : 69.5260%
# Epoch [138], train_Loss : 0.0058, val_Loss : 0.0391,                train_accuracy : 93.1442%, val_accuracy : 69.3002%
# Epoch [139], train_Loss : 0.0056, val_Loss : 0.0398,                train_accuracy : 93.4397%, val_accuracy : 68.8488%
# Epoch [140], train_Loss : 0.0057, val_Loss : 0.0419,                train_accuracy : 93.0851%, val_accuracy : 68.6230%
# Epoch [141], train_Loss : 0.0067, val_Loss : 0.0389,                train_accuracy : 92.4350%, val_accuracy : 69.3002%
# Epoch [142], train_Loss : 0.0050, val_Loss : 0.0404,                train_accuracy : 94.1489%, val_accuracy : 69.0745%
# Epoch [143], train_Loss : 0.0052, val_Loss : 0.0409,                train_accuracy : 93.3806%, val_accuracy : 69.7517%
# Epoch [144], train_Loss : 0.0068, val_Loss : 0.0413,                train_accuracy : 91.7849%, val_accuracy : 66.8172%
# Epoch [145], train_Loss : 0.0068, val_Loss : 0.0389,                train_accuracy : 91.8440%, val_accuracy : 68.8488%
# Epoch [146], train_Loss : 0.0057, val_Loss : 0.0385,                train_accuracy : 93.3806%, val_accuracy : 69.0745%
# Epoch [147], train_Loss : 0.0060, val_Loss : 0.0363,                train_accuracy : 92.9078%, val_accuracy : 69.7517%
# Epoch [148], train_Loss : 0.0050, val_Loss : 0.0393,                train_accuracy : 94.2671%, val_accuracy : 69.7517%
# Epoch [149], train_Loss : 0.0064, val_Loss : 0.0382,                train_accuracy : 92.4350%, val_accuracy : 68.1716%
# Epoch [150], train_Loss : 0.0058, val_Loss : 0.0403,                train_accuracy : 92.7305%, val_accuracy : 69.3002%
# Epoch [151], train_Loss : 0.0054, val_Loss : 0.0390,                train_accuracy : 93.5579%, val_accuracy : 70.6546%
# Epoch [152], train_Loss : 0.0058, val_Loss : 0.0417,                train_accuracy : 93.3215%, val_accuracy : 68.3973%
# Epoch [153], train_Loss : 0.0058, val_Loss : 0.0414,                train_accuracy : 93.0851%, val_accuracy : 68.1716%
# Epoch [154], train_Loss : 0.0056, val_Loss : 0.0382,                train_accuracy : 93.6170%, val_accuracy : 68.8488%
# Epoch [155], train_Loss : 0.0066, val_Loss : 0.0397,                train_accuracy : 91.3121%, val_accuracy : 68.3973%
# Epoch [156], train_Loss : 0.0057, val_Loss : 0.0393,                train_accuracy : 93.3806%, val_accuracy : 68.3973%
# Epoch [157], train_Loss : 0.0051, val_Loss : 0.0407,                train_accuracy : 94.3262%, val_accuracy : 68.1716%
# Epoch [158], train_Loss : 0.0064, val_Loss : 0.0401,                train_accuracy : 92.1395%, val_accuracy : 70.6546%
# Epoch [159], train_Loss : 0.0056, val_Loss : 0.0374,                train_accuracy : 93.7943%, val_accuracy : 68.3973%
# Epoch [160], train_Loss : 0.0056, val_Loss : 0.0387,                train_accuracy : 93.4988%, val_accuracy : 69.9774%
# Epoch [161], train_Loss : 0.0053, val_Loss : 0.0386,                train_accuracy : 94.3262%, val_accuracy : 69.9774%
# Epoch [162], train_Loss : 0.0052, val_Loss : 0.0392,                train_accuracy : 94.4444%, val_accuracy : 70.8804%
# Epoch [163], train_Loss : 0.0056, val_Loss : 0.0378,                train_accuracy : 93.3215%, val_accuracy : 68.8488%
# Epoch [164], train_Loss : 0.0056, val_Loss : 0.0397,                train_accuracy : 93.7943%, val_accuracy : 69.7517%
# Epoch [165], train_Loss : 0.0067, val_Loss : 0.0414,                train_accuracy : 93.0260%, val_accuracy : 67.7201%
# Epoch [166], train_Loss : 0.0070, val_Loss : 0.0381,                train_accuracy : 91.3712%, val_accuracy : 69.7517%
# Epoch [167], train_Loss : 0.0051, val_Loss : 0.0384,                train_accuracy : 93.5579%, val_accuracy : 69.7517%
# Epoch [168], train_Loss : 0.0048, val_Loss : 0.0405,                train_accuracy : 94.6809%, val_accuracy : 68.8488%
# Epoch [169], train_Loss : 0.0052, val_Loss : 0.0420,                train_accuracy : 93.7352%, val_accuracy : 68.3973%
# Epoch [170], train_Loss : 0.0060, val_Loss : 0.0399,                train_accuracy : 92.8487%, val_accuracy : 68.8488%
# Epoch [171], train_Loss : 0.0049, val_Loss : 0.0402,                train_accuracy : 94.6217%, val_accuracy : 69.9774%
# Epoch [172], train_Loss : 0.0046, val_Loss : 0.0421,                train_accuracy : 93.9716%, val_accuracy : 69.3002%
# Epoch [173], train_Loss : 0.0048, val_Loss : 0.0448,                train_accuracy : 93.6761%, val_accuracy : 67.7201%
# Epoch [174], train_Loss : 0.0052, val_Loss : 0.0407,                train_accuracy : 94.2671%, val_accuracy : 69.0745%
# Epoch [175], train_Loss : 0.0046, val_Loss : 0.0436,                train_accuracy : 94.2080%, val_accuracy : 68.1716%
# Epoch [176], train_Loss : 0.0051, val_Loss : 0.0430,                train_accuracy : 93.8534%, val_accuracy : 69.7517%
# Epoch [177], train_Loss : 0.0058, val_Loss : 0.0400,                train_accuracy : 92.9078%, val_accuracy : 69.0745%
# Epoch [178], train_Loss : 0.0056, val_Loss : 0.0406,                train_accuracy : 93.1442%, val_accuracy : 66.5914%
# Epoch [179], train_Loss : 0.0050, val_Loss : 0.0382,                train_accuracy : 94.2080%, val_accuracy : 66.8172%
# Epoch [180], train_Loss : 0.0043, val_Loss : 0.0405,                train_accuracy : 94.7991%, val_accuracy : 70.2032%
# Epoch [181], train_Loss : 0.0052, val_Loss : 0.0414,                train_accuracy : 94.3853%, val_accuracy : 70.2032%
# Epoch [182], train_Loss : 0.0048, val_Loss : 0.0429,                train_accuracy : 94.7400%, val_accuracy : 69.0745%
# Epoch [183], train_Loss : 0.0058, val_Loss : 0.0437,                train_accuracy : 92.8487%, val_accuracy : 67.4944%
# Epoch [184], train_Loss : 0.0059, val_Loss : 0.0408,                train_accuracy : 93.1442%, val_accuracy : 69.9774%
# Epoch [185], train_Loss : 0.0057, val_Loss : 0.0379,                train_accuracy : 93.6170%, val_accuracy : 70.2032%
# Epoch [186], train_Loss : 0.0056, val_Loss : 0.0394,                train_accuracy : 93.4397%, val_accuracy : 68.6230%
# Epoch [187], train_Loss : 0.0053, val_Loss : 0.0394,                train_accuracy : 93.9125%, val_accuracy : 69.3002%
# Epoch [188], train_Loss : 0.0047, val_Loss : 0.0409,                train_accuracy : 94.2080%, val_accuracy : 68.6230%
# Epoch [189], train_Loss : 0.0048, val_Loss : 0.0396,                train_accuracy : 94.6217%, val_accuracy : 70.2032%
# Epoch [190], train_Loss : 0.0048, val_Loss : 0.0429,                train_accuracy : 93.9716%, val_accuracy : 68.8488%
# Epoch [191], train_Loss : 0.0047, val_Loss : 0.0404,                train_accuracy : 94.2671%, val_accuracy : 68.8488%
# Epoch [192], train_Loss : 0.0054, val_Loss : 0.0392,                train_accuracy : 93.5579%, val_accuracy : 69.5260%
# Epoch [193], train_Loss : 0.0055, val_Loss : 0.0386,                train_accuracy : 94.2080%, val_accuracy : 68.6230%
# Epoch [194], train_Loss : 0.0053, val_Loss : 0.0378,                train_accuracy : 94.2671%, val_accuracy : 71.5576%
# Epoch [195], train_Loss : 0.0051, val_Loss : 0.0412,                train_accuracy : 93.9125%, val_accuracy : 67.7201%
# Epoch [196], train_Loss : 0.0051, val_Loss : 0.0415,                train_accuracy : 94.0898%, val_accuracy : 69.0745%
# Epoch [197], train_Loss : 0.0053, val_Loss : 0.0398,                train_accuracy : 93.3806%, val_accuracy : 69.7517%
# Epoch [198], train_Loss : 0.0046, val_Loss : 0.0398,                train_accuracy : 95.2128%, val_accuracy : 70.4289%
# Epoch [199], train_Loss : 0.0040, val_Loss : 0.0421,                train_accuracy : 95.0946%, val_accuracy : 68.6230%
# Epoch [200], train_Loss : 0.0045, val_Loss : 0.0431,                train_accuracy : 94.8582%, val_accuracy : 67.0429%

# %%
model = CNN().to(device)
model.load_state_dict(torch.load('CNN_2nd_update.pt'))
model.eval()
test_loss, test_acc = predict(model, optimizer, criterion, test_dataloader)

print(f'Test_Loss : {test_loss:.4f},Test_Accuracy : {100*test_acc:.4f}%')
# Out:
# Test_Loss : 0.0373,Test_Accuracy : 71.5576%

# %%
num_epochs = 200
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)
ax.plot(range(num_epochs), train_loss_list, c='b', label='train loss')
ax.plot(range(num_epochs), test_loss_list, c='r', label='val loss')
ax.set_xlabel('epoch', fontsize='20')
ax.set_ylabel('loss', fontsize='20')
ax.set_title('train and val loss', fontsize='20')
ax.grid()
ax.legend(fontsize='25')
plt.show()

# %%
num_epochs = 200
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)
ax.plot(range(num_epochs), train_acc_list, c='b', label='train accuracy')
ax.plot(range(num_epochs), test_acc_list, c='r', label='val accuracy')
ax.set_xlabel('epoch', fontsize='20')
ax.set_ylabel('accuracy', fontsize='20')
ax.set_title('train and val accuracy', fontsize='20')
ax.grid()
ax.legend(fontsize='25')
plt.show()

# %%
from torchsummary import summary
model = CNN()
summary(model, (1, 22, 1000))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 22, 1000]           2,080
#        BatchNorm2d-2         [-1, 32, 22, 1000]              64
#             Conv2d-3          [-1, 64, 1, 1000]          45,120
#        BatchNorm2d-4          [-1, 64, 1, 1000]             128
#                ELU-5          [-1, 64, 1, 1000]               0
#          AvgPool2d-6           [-1, 64, 1, 200]               0
#            Dropout-7           [-1, 64, 1, 200]               0
#             Conv2d-8           [-1, 64, 1, 200]          65,600
#             Conv2d-9           [-1, 64, 1, 200]           4,160
#       BatchNorm2d-10           [-1, 64, 1, 200]             128
#               ELU-11           [-1, 64, 1, 200]               0
#         AvgPool2d-12            [-1, 64, 1, 40]               0
#           Dropout-13            [-1, 64, 1, 40]               0
#            Linear-14                  [-1, 256]         655,616
#            Linear-15                    [-1, 4]           1,028
# ================================================================
# Total params: 773,924
# Trainable params: 773,924
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.08
# Forward/backward pass size (MB): 12.83
# Params size (MB): 2.95
# Estimated Total Size (MB): 15.87
# ----------------------------------------------------------------
