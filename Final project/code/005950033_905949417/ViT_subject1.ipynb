# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
device = "mps" if torch.backends.mps.is_available() else "cpu"
device = torch.device(device)
print('Using {} device'.format(device))
device = torch.device('cpu')
# Out:
# Using mps device

# %%
X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")
y_test -= 769
y_train_valid -= 769

# %%
train_valid_1_idx = list(np.where(person_train_valid==1)[0])
X_train_valid_1 = X_train_valid[train_valid_1_idx]
y_train_valid_1 = y_train_valid[train_valid_1_idx]
test_1_idx = list(np.where(person_test==1)[0])
X_test_1 = X_test[test_1_idx]
y_test_1 = y_test[test_1_idx]

# %%
idx_val = np.random.choice(236, 47, replace=False)
idx_tra = np.array(list(set(range(236)).difference(set(idx_val))))
X_train, X_val = X_train_valid_1[idx_tra], X_train_valid_1[idx_val] 
y_train, y_val = y_train_valid_1[idx_tra], y_train_valid_1[idx_val]
X_test = X_test_1
y_test = y_test_1

# %% [markdown]
# ### Shape of data

# %%
print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (50, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (50,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %% [markdown]
# # To torch.tensor

# %%
X_train = torch.from_numpy(X_train).float()
X_train = X_train[:,None,:,:]
y_train = torch.from_numpy(y_train).long()
X_val = torch.from_numpy(X_val).float()
X_val = X_val[:,None,:,:]
y_val = torch.from_numpy(y_val).long()
X_test = torch.from_numpy(X_test).float()
X_test = X_test[:,None,:,:]
y_test = torch.from_numpy(y_test).long()

# %% [markdown]
# # Dataset Class

# %%
train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
val_dataset = torch.utils.data.TensorDataset(X_val, y_val)
test_dataset = torch.utils.data.TensorDataset(X_test, y_test)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# # Network

# %%
class MSA(nn.Module):
    def __init__(self, hidden_d, n_heads=2):
        super(MSA, self).__init__()
        self.d = hidden_d
        self.n_heads = n_heads

        d_head = int(self.d / n_heads)
        self.q_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.k_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.v_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.d_head = d_head
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, sequences):
        # Sequences has shape (N, seq_length, token_dim)
        # We go into shape    (N, seq_length, n_heads, token_dim / n_heads)
        # And come back to    (N, seq_length, item_dim)  (through concatenation)
        result = []
        for sequence in sequences:
            seq_result = []
            for head in range(self.n_heads):
                q_mapping = self.q_mappings[head]
                k_mapping = self.k_mappings[head]
                v_mapping = self.v_mappings[head]

                seq = sequence[:, head * self.d_head: (head + 1) * self.d_head]
                q, k, v = q_mapping(seq), k_mapping(seq), v_mapping(seq)

                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                seq_result.append(attention @ v)
            result.append(torch.hstack(seq_result))
        return torch.cat([torch.unsqueeze(r, dim=0) for r in result])

# %%
class ViTBlock(nn.Module):
    def __init__(self, hidden_d, n_heads, mlp_ratio=4):
        super(ViTBlock, self).__init__()
        self.hidden_d = hidden_d
        self.n_heads = n_heads

        self.norm1 = nn.LayerNorm(hidden_d)
        self.mhsa = MSA(hidden_d, n_heads)
        self.norm2 = nn.LayerNorm(hidden_d)
        self.mlp = nn.Sequential(
            nn.Linear(hidden_d, mlp_ratio * hidden_d),
            nn.GELU(),
            nn.Linear(mlp_ratio * hidden_d, hidden_d)
        )

    def forward(self, x):
        out = x + self.mhsa(self.norm1(x))
        out = out + self.mlp(self.norm2(out))
        return out

# %%
def patch_gen(x, patch_h, patch_w):
    n, c, h, w = x.shape
    patch_num_h = int(22/patch_h)
    patch_num_w = int(1000/patch_w)
    patch_num = patch_num_h * patch_num_w
    patch_size = patch_h * patch_w
    patches = torch.zeros(n, patch_num, patch_size)

    for idx, x_ in enumerate(x):
        for i in range(patch_num_h):
            for j in range(patch_num_w):
                patch = x_[:, i * patch_h:(i + 1) * patch_h, j * patch_w:(j + 1) * patch_w]
                patches[idx,i*patch_num_w+j,:] = patch.flatten()
    return patches.to(device)
    
def get_positional_embeddings(sequence_length, d):
    result = torch.ones(sequence_length, d)
    for i in range(sequence_length):
        for j in range(d):
            result[i][j] = np.sin(i / (10000 ** (j / d))) if j % 2 == 0 else np.cos(i / (10000 ** ((j - 1) / d)))
    return result.to(device)

# %%
class ViT(nn.Module):
    def __init__(self, patch_h, patch_w, hidden_d, n_blocks=2, n_heads=2, out_d=4):
        super(ViT, self).__init__()
        self.hidden_d = hidden_d
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.patch_h = patch_h
        self.patch_w = patch_w
        self.patch_num_h = int(22/patch_h)
        self.patch_num_w = int(1000/patch_w)

        #Linear mapper
        self.linear_mapper = nn.Linear(patch_h*patch_w, self.hidden_d)
        #Classifiation token
        self.class_token = nn.Parameter(torch.rand(1, self.hidden_d))
        #Positional embedding
        self.register_buffer('positional_embeddings', get_positional_embeddings(self.patch_num_h*self.patch_num_w+1, hidden_d), persistent=False)
        #Transformer encoder blocks
        self.blocks = nn.ModuleList([ViTBlock(hidden_d, n_heads) for _ in range(n_blocks)])
        #MLP
        self.mlp = nn.Sequential(
            nn.Linear(self.hidden_d, out_d),
            nn.Softmax(dim=-1)
        )
    def forward(self, x):
        n, c, h, w = x.shape
        patches = patch_gen(x,self.patch_h,self.patch_w).to(self.positional_embeddings.device)
        tokens = self.linear_mapper(patches)
        #Add classification token to the tokens
        tokens = torch.cat((self.class_token.expand(n, 1, -1), tokens), dim=1)
        # Adding positional embedding
        out = tokens + self.positional_embeddings.repeat(n, 1, 1)

        for block in self.blocks:
            out = block(out)

        out = out[:, 0]

        return self.mlp(out)

# %%
def train_epoch(model, optimizer, criterion, dataloader):
    train_loss = 0
    train_acc = 0
    model.train()
    for i, (inp, labels) in enumerate(dataloader):
        inp, labels = inp.to(device), labels.to(device)
        optimizer.zero_grad()
        outp = model(inp)
        outp_pred = torch.max(outp,axis=1).indices
        train_acc += torch.sum(outp_pred == labels)
        loss = criterion(outp, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss = train_loss / len(train_dataloader.dataset)
    train_acc = train_acc/ len(train_dataloader.dataset)
    return train_loss, train_acc

# %%
def predict(model, optimizer, criterion, dataloader, pred_loader=test_dataloader):
    test_loss = 0
    test_acc = 0
    best_acc = 0
    model.eval()
    with torch.no_grad():
        for i, (inp, labels) in enumerate(pred_loader):
            inp, labels = inp.to(device), labels.to(device)
            outp = model(inp)
            outp_pred = torch.max(outp,axis=1).indices
            test_acc += torch.sum(outp_pred == labels)
            loss = criterion(outp, labels)
            test_loss += loss.item()
        test_loss = test_loss / len(pred_loader.dataset)
        test_acc = test_acc / len(pred_loader.dataset)
    return test_loss, test_acc

# %%
acc_device = torch.device('cpu')
def run(num_epochs, optimizer, criterion, pred_loader=test_dataloader):
    train_loss_list = []
    test_loss_list = []
    train_acc_list = []
    test_acc_list = []
    best_acc = 0
    for epoch in range(num_epochs):
        train_loss, train_acc = train_epoch(model, optimizer, criterion, train_dataloader)
        test_loss, test_acc = predict(model, optimizer, criterion, pred_loader)
        # if epoch % 5 == 0:
        #     print(f'Epoch [{epoch+1}], train_Loss : {train_loss:.4f}, val_Loss : {test_loss:.4f},\
        #         train_accuracy : {100*train_acc:.4f}%, val_accuracy : {100*test_acc:.4f}%')
        print(f'Epoch [{epoch+1}], train_Loss : {train_loss:.4f}, val_Loss : {test_loss:.4f},\
                train_accuracy : {100*train_acc:.4f}%, val_accuracy : {100*test_acc:.4f}%')
        train_loss_list.append(train_loss)
        test_loss_list.append(test_loss)
        train_acc_list.append(train_acc.to(acc_device))
        test_acc_list.append(test_acc.to(acc_device))

        if test_acc > best_acc and pred_loader != test_dataloader:
            torch.save(model.state_dict(), 'ViT_subject1.pt')
            best_acc = test_acc
    return train_loss_list, test_loss_list, train_acc_list, test_acc_list

# %%
# best model
#ViT(patch_h=22, patch_w=5, hidden_d=8, n_blocks=2, n_heads=2)

# %%
model = ViT(patch_h=22, patch_w=2, hidden_d=8, n_blocks=2, n_heads=2).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
train_loss_list, test_loss_list, train_acc_list, test_acc_list = run(200, optimizer, criterion, val_dataloader)
# Out:
# Epoch [1], train_Loss : 0.0441, val_Loss : 0.0554,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [2], train_Loss : 0.0440, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [3], train_Loss : 0.0440, val_Loss : 0.0554,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [4], train_Loss : 0.0440, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [5], train_Loss : 0.0440, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [6], train_Loss : 0.0440, val_Loss : 0.0556,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [7], train_Loss : 0.0440, val_Loss : 0.0555,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [8], train_Loss : 0.0440, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [9], train_Loss : 0.0440, val_Loss : 0.0555,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [10], train_Loss : 0.0440, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [11], train_Loss : 0.0439, val_Loss : 0.0559,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [12], train_Loss : 0.0440, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [13], train_Loss : 0.0439, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [14], train_Loss : 0.0439, val_Loss : 0.0558,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [15], train_Loss : 0.0439, val_Loss : 0.0558,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [16], train_Loss : 0.0439, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [17], train_Loss : 0.0439, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [18], train_Loss : 0.0439, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [19], train_Loss : 0.0439, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [20], train_Loss : 0.0439, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [21], train_Loss : 0.0439, val_Loss : 0.0556,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [22], train_Loss : 0.0439, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [23], train_Loss : 0.0439, val_Loss : 0.0556,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [24], train_Loss : 0.0439, val_Loss : 0.0556,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [25], train_Loss : 0.0439, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [26], train_Loss : 0.0439, val_Loss : 0.0556,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [27], train_Loss : 0.0439, val_Loss : 0.0557,                train_accuracy : 26.9841%, val_accuracy : 24.0000%
# Epoch [28], train_Loss : 0.0439, val_Loss : 0.0556,                train_accuracy : 27.5132%, val_accuracy : 24.0000%
# Epoch [29], train_Loss : 0.0439, val_Loss : 0.0557,                train_accuracy : 29.6296%, val_accuracy : 22.0000%
# Epoch [30], train_Loss : 0.0438, val_Loss : 0.0556,                train_accuracy : 29.6296%, val_accuracy : 24.0000%
# Epoch [31], train_Loss : 0.0438, val_Loss : 0.0556,                train_accuracy : 29.1005%, val_accuracy : 24.0000%
# Epoch [32], train_Loss : 0.0438, val_Loss : 0.0555,                train_accuracy : 28.0423%, val_accuracy : 24.0000%
# Epoch [33], train_Loss : 0.0438, val_Loss : 0.0556,                train_accuracy : 28.0423%, val_accuracy : 24.0000%
# Epoch [34], train_Loss : 0.0438, val_Loss : 0.0556,                train_accuracy : 29.1005%, val_accuracy : 26.0000%
# Epoch [35], train_Loss : 0.0438, val_Loss : 0.0557,                train_accuracy : 30.1587%, val_accuracy : 28.0000%
# Epoch [36], train_Loss : 0.0437, val_Loss : 0.0556,                train_accuracy : 30.1587%, val_accuracy : 28.0000%
# Epoch [37], train_Loss : 0.0437, val_Loss : 0.0556,                train_accuracy : 29.6296%, val_accuracy : 22.0000%
# Epoch [38], train_Loss : 0.0437, val_Loss : 0.0554,                train_accuracy : 29.1005%, val_accuracy : 26.0000%
# Epoch [39], train_Loss : 0.0437, val_Loss : 0.0556,                train_accuracy : 30.6878%, val_accuracy : 26.0000%
# Epoch [40], train_Loss : 0.0437, val_Loss : 0.0556,                train_accuracy : 30.1587%, val_accuracy : 22.0000%
# Epoch [41], train_Loss : 0.0436, val_Loss : 0.0554,                train_accuracy : 31.7460%, val_accuracy : 26.0000%
# Epoch [42], train_Loss : 0.0435, val_Loss : 0.0556,                train_accuracy : 32.2751%, val_accuracy : 24.0000%
# Epoch [43], train_Loss : 0.0436, val_Loss : 0.0554,                train_accuracy : 28.0423%, val_accuracy : 24.0000%
# Epoch [44], train_Loss : 0.0434, val_Loss : 0.0552,                train_accuracy : 35.4497%, val_accuracy : 30.0000%
# Epoch [45], train_Loss : 0.0434, val_Loss : 0.0553,                train_accuracy : 31.7460%, val_accuracy : 30.0000%
# Epoch [46], train_Loss : 0.0431, val_Loss : 0.0554,                train_accuracy : 35.4497%, val_accuracy : 22.0000%
# Epoch [47], train_Loss : 0.0431, val_Loss : 0.0550,                train_accuracy : 32.8042%, val_accuracy : 28.0000%
# Epoch [48], train_Loss : 0.0434, val_Loss : 0.0555,                train_accuracy : 27.5132%, val_accuracy : 26.0000%
# Epoch [49], train_Loss : 0.0435, val_Loss : 0.0554,                train_accuracy : 30.6878%, val_accuracy : 24.0000%
# Epoch [50], train_Loss : 0.0434, val_Loss : 0.0556,                train_accuracy : 27.5132%, val_accuracy : 22.0000%
# Epoch [51], train_Loss : 0.0431, val_Loss : 0.0548,                train_accuracy : 32.2751%, val_accuracy : 34.0000%
# Epoch [52], train_Loss : 0.0426, val_Loss : 0.0553,                train_accuracy : 42.3280%, val_accuracy : 24.0000%
# Epoch [53], train_Loss : 0.0432, val_Loss : 0.0545,                train_accuracy : 29.6296%, val_accuracy : 24.0000%
# Epoch [54], train_Loss : 0.0432, val_Loss : 0.0547,                train_accuracy : 28.0423%, val_accuracy : 36.0000%
# Epoch [55], train_Loss : 0.0423, val_Loss : 0.0561,                train_accuracy : 43.3862%, val_accuracy : 26.0000%
# Epoch [56], train_Loss : 0.0423, val_Loss : 0.0551,                train_accuracy : 34.9206%, val_accuracy : 28.0000%
# Epoch [57], train_Loss : 0.0425, val_Loss : 0.0550,                train_accuracy : 39.1534%, val_accuracy : 28.0000%
# Epoch [58], train_Loss : 0.0422, val_Loss : 0.0549,                train_accuracy : 38.0952%, val_accuracy : 28.0000%
# Epoch [59], train_Loss : 0.0422, val_Loss : 0.0543,                train_accuracy : 41.2698%, val_accuracy : 36.0000%
# Epoch [60], train_Loss : 0.0415, val_Loss : 0.0554,                train_accuracy : 41.7989%, val_accuracy : 36.0000%
# Epoch [61], train_Loss : 0.0416, val_Loss : 0.0556,                train_accuracy : 41.7989%, val_accuracy : 34.0000%
# Epoch [62], train_Loss : 0.0416, val_Loss : 0.0546,                train_accuracy : 40.7407%, val_accuracy : 28.0000%
# Epoch [63], train_Loss : 0.0414, val_Loss : 0.0545,                train_accuracy : 38.0952%, val_accuracy : 30.0000%
# Epoch [64], train_Loss : 0.0412, val_Loss : 0.0543,                train_accuracy : 37.0370%, val_accuracy : 30.0000%
# Epoch [65], train_Loss : 0.0408, val_Loss : 0.0546,                train_accuracy : 39.6825%, val_accuracy : 30.0000%
# Epoch [66], train_Loss : 0.0407, val_Loss : 0.0550,                train_accuracy : 41.2698%, val_accuracy : 30.0000%
# Epoch [67], train_Loss : 0.0407, val_Loss : 0.0546,                train_accuracy : 42.8571%, val_accuracy : 34.0000%
# Epoch [68], train_Loss : 0.0406, val_Loss : 0.0540,                train_accuracy : 41.2698%, val_accuracy : 36.0000%
# Epoch [69], train_Loss : 0.0402, val_Loss : 0.0557,                train_accuracy : 43.3862%, val_accuracy : 28.0000%
# Epoch [70], train_Loss : 0.0403, val_Loss : 0.0542,                train_accuracy : 46.0317%, val_accuracy : 30.0000%
# Epoch [71], train_Loss : 0.0407, val_Loss : 0.0549,                train_accuracy : 39.1534%, val_accuracy : 30.0000%
# Epoch [72], train_Loss : 0.0401, val_Loss : 0.0550,                train_accuracy : 47.0899%, val_accuracy : 38.0000%
# Epoch [73], train_Loss : 0.0401, val_Loss : 0.0550,                train_accuracy : 43.9153%, val_accuracy : 32.0000%
# Epoch [74], train_Loss : 0.0399, val_Loss : 0.0536,                train_accuracy : 45.5026%, val_accuracy : 30.0000%
# Epoch [75], train_Loss : 0.0399, val_Loss : 0.0553,                train_accuracy : 47.0899%, val_accuracy : 30.0000%
# Epoch [76], train_Loss : 0.0402, val_Loss : 0.0547,                train_accuracy : 43.9153%, val_accuracy : 32.0000%
# Epoch [77], train_Loss : 0.0398, val_Loss : 0.0543,                train_accuracy : 49.2063%, val_accuracy : 38.0000%
# Epoch [78], train_Loss : 0.0398, val_Loss : 0.0544,                train_accuracy : 44.4444%, val_accuracy : 38.0000%
# Epoch [79], train_Loss : 0.0393, val_Loss : 0.0542,                train_accuracy : 50.7937%, val_accuracy : 32.0000%
# Epoch [80], train_Loss : 0.0391, val_Loss : 0.0546,                train_accuracy : 50.7937%, val_accuracy : 28.0000%
# Epoch [81], train_Loss : 0.0385, val_Loss : 0.0561,                train_accuracy : 53.9683%, val_accuracy : 32.0000%
# Epoch [82], train_Loss : 0.0386, val_Loss : 0.0553,                train_accuracy : 52.9101%, val_accuracy : 28.0000%
# Epoch [83], train_Loss : 0.0378, val_Loss : 0.0543,                train_accuracy : 54.4974%, val_accuracy : 34.0000%
# Epoch [84], train_Loss : 0.0376, val_Loss : 0.0544,                train_accuracy : 56.0847%, val_accuracy : 30.0000%
# Epoch [85], train_Loss : 0.0379, val_Loss : 0.0553,                train_accuracy : 53.4392%, val_accuracy : 28.0000%
# Epoch [86], train_Loss : 0.0370, val_Loss : 0.0558,                train_accuracy : 58.2011%, val_accuracy : 32.0000%
# Epoch [87], train_Loss : 0.0373, val_Loss : 0.0564,                train_accuracy : 56.6138%, val_accuracy : 28.0000%
# Epoch [88], train_Loss : 0.0404, val_Loss : 0.0588,                train_accuracy : 44.4444%, val_accuracy : 26.0000%
# Epoch [89], train_Loss : 0.0392, val_Loss : 0.0561,                train_accuracy : 49.2063%, val_accuracy : 28.0000%
# Epoch [90], train_Loss : 0.0395, val_Loss : 0.0555,                train_accuracy : 46.5608%, val_accuracy : 30.0000%
# Epoch [91], train_Loss : 0.0385, val_Loss : 0.0557,                train_accuracy : 52.3810%, val_accuracy : 32.0000%
# Epoch [92], train_Loss : 0.0374, val_Loss : 0.0549,                train_accuracy : 56.6138%, val_accuracy : 36.0000%
# Epoch [93], train_Loss : 0.0371, val_Loss : 0.0556,                train_accuracy : 58.7302%, val_accuracy : 28.0000%
# Epoch [94], train_Loss : 0.0367, val_Loss : 0.0558,                train_accuracy : 58.7302%, val_accuracy : 34.0000%
# Epoch [95], train_Loss : 0.0368, val_Loss : 0.0555,                train_accuracy : 57.1429%, val_accuracy : 30.0000%
# Epoch [96], train_Loss : 0.0381, val_Loss : 0.0562,                train_accuracy : 53.9683%, val_accuracy : 30.0000%
# Epoch [97], train_Loss : 0.0387, val_Loss : 0.0533,                train_accuracy : 50.7937%, val_accuracy : 36.0000%
# Epoch [98], train_Loss : 0.0376, val_Loss : 0.0549,                train_accuracy : 54.4974%, val_accuracy : 28.0000%
# Epoch [99], train_Loss : 0.0362, val_Loss : 0.0548,                train_accuracy : 59.7884%, val_accuracy : 32.0000%
# Epoch [100], train_Loss : 0.0362, val_Loss : 0.0555,                train_accuracy : 60.8466%, val_accuracy : 32.0000%
# Epoch [101], train_Loss : 0.0365, val_Loss : 0.0562,                train_accuracy : 58.7302%, val_accuracy : 30.0000%
# Epoch [102], train_Loss : 0.0361, val_Loss : 0.0570,                train_accuracy : 59.7884%, val_accuracy : 32.0000%
# Epoch [103], train_Loss : 0.0358, val_Loss : 0.0543,                train_accuracy : 59.7884%, val_accuracy : 34.0000%
# Epoch [104], train_Loss : 0.0358, val_Loss : 0.0556,                train_accuracy : 62.9630%, val_accuracy : 32.0000%
# Epoch [105], train_Loss : 0.0351, val_Loss : 0.0559,                train_accuracy : 63.4921%, val_accuracy : 34.0000%
# Epoch [106], train_Loss : 0.0352, val_Loss : 0.0568,                train_accuracy : 62.9630%, val_accuracy : 28.0000%
# Epoch [107], train_Loss : 0.0363, val_Loss : 0.0560,                train_accuracy : 59.2593%, val_accuracy : 34.0000%
# Epoch [108], train_Loss : 0.0363, val_Loss : 0.0569,                train_accuracy : 60.3175%, val_accuracy : 26.0000%
# Epoch [109], train_Loss : 0.0352, val_Loss : 0.0567,                train_accuracy : 63.4921%, val_accuracy : 30.0000%
# Epoch [110], train_Loss : 0.0350, val_Loss : 0.0566,                train_accuracy : 63.4921%, val_accuracy : 30.0000%
# Epoch [111], train_Loss : 0.0346, val_Loss : 0.0564,                train_accuracy : 66.1376%, val_accuracy : 32.0000%
# Epoch [112], train_Loss : 0.0342, val_Loss : 0.0568,                train_accuracy : 67.7249%, val_accuracy : 28.0000%
# Epoch [113], train_Loss : 0.0346, val_Loss : 0.0556,                train_accuracy : 65.0794%, val_accuracy : 28.0000%
# Epoch [114], train_Loss : 0.0352, val_Loss : 0.0557,                train_accuracy : 64.0212%, val_accuracy : 32.0000%
# Epoch [115], train_Loss : 0.0369, val_Loss : 0.0577,                train_accuracy : 57.6720%, val_accuracy : 32.0000%
# Epoch [116], train_Loss : 0.0356, val_Loss : 0.0553,                train_accuracy : 61.9048%, val_accuracy : 30.0000%
# Epoch [117], train_Loss : 0.0370, val_Loss : 0.0563,                train_accuracy : 58.7302%, val_accuracy : 28.0000%
# Epoch [118], train_Loss : 0.0365, val_Loss : 0.0560,                train_accuracy : 58.2011%, val_accuracy : 28.0000%
# Epoch [119], train_Loss : 0.0344, val_Loss : 0.0566,                train_accuracy : 65.6085%, val_accuracy : 30.0000%
# Epoch [120], train_Loss : 0.0355, val_Loss : 0.0554,                train_accuracy : 62.9630%, val_accuracy : 30.0000%
# Epoch [121], train_Loss : 0.0357, val_Loss : 0.0550,                train_accuracy : 61.9048%, val_accuracy : 32.0000%
# Epoch [122], train_Loss : 0.0346, val_Loss : 0.0556,                train_accuracy : 64.5503%, val_accuracy : 34.0000%
# Epoch [123], train_Loss : 0.0341, val_Loss : 0.0565,                train_accuracy : 68.2540%, val_accuracy : 30.0000%
# Epoch [124], train_Loss : 0.0337, val_Loss : 0.0564,                train_accuracy : 70.3704%, val_accuracy : 30.0000%
# Epoch [125], train_Loss : 0.0339, val_Loss : 0.0576,                train_accuracy : 67.1958%, val_accuracy : 30.0000%
# Epoch [126], train_Loss : 0.0339, val_Loss : 0.0553,                train_accuracy : 68.7831%, val_accuracy : 34.0000%
# Epoch [127], train_Loss : 0.0341, val_Loss : 0.0554,                train_accuracy : 66.6667%, val_accuracy : 32.0000%
# Epoch [128], train_Loss : 0.0340, val_Loss : 0.0553,                train_accuracy : 67.7249%, val_accuracy : 34.0000%
# Epoch [129], train_Loss : 0.0347, val_Loss : 0.0552,                train_accuracy : 65.6085%, val_accuracy : 30.0000%
# Epoch [130], train_Loss : 0.0348, val_Loss : 0.0565,                train_accuracy : 63.4921%, val_accuracy : 34.0000%
# Epoch [131], train_Loss : 0.0347, val_Loss : 0.0573,                train_accuracy : 64.0212%, val_accuracy : 28.0000%
# Epoch [132], train_Loss : 0.0342, val_Loss : 0.0563,                train_accuracy : 68.2540%, val_accuracy : 32.0000%
# Epoch [133], train_Loss : 0.0347, val_Loss : 0.0547,                train_accuracy : 64.0212%, val_accuracy : 30.0000%
# Epoch [134], train_Loss : 0.0341, val_Loss : 0.0553,                train_accuracy : 66.6667%, val_accuracy : 36.0000%
# Epoch [135], train_Loss : 0.0334, val_Loss : 0.0552,                train_accuracy : 70.8995%, val_accuracy : 32.0000%
# Epoch [136], train_Loss : 0.0333, val_Loss : 0.0559,                train_accuracy : 70.3704%, val_accuracy : 36.0000%
# Epoch [137], train_Loss : 0.0330, val_Loss : 0.0556,                train_accuracy : 70.3704%, val_accuracy : 32.0000%
# Epoch [138], train_Loss : 0.0330, val_Loss : 0.0559,                train_accuracy : 71.9577%, val_accuracy : 30.0000%
# Epoch [139], train_Loss : 0.0331, val_Loss : 0.0555,                train_accuracy : 70.3704%, val_accuracy : 30.0000%
# Epoch [140], train_Loss : 0.0328, val_Loss : 0.0571,                train_accuracy : 73.0159%, val_accuracy : 30.0000%
# Epoch [141], train_Loss : 0.0324, val_Loss : 0.0565,                train_accuracy : 74.6032%, val_accuracy : 32.0000%
# Epoch [142], train_Loss : 0.0324, val_Loss : 0.0558,                train_accuracy : 73.5450%, val_accuracy : 30.0000%
# Epoch [143], train_Loss : 0.0322, val_Loss : 0.0566,                train_accuracy : 74.6032%, val_accuracy : 30.0000%
# Epoch [144], train_Loss : 0.0327, val_Loss : 0.0566,                train_accuracy : 74.0741%, val_accuracy : 32.0000%
# Epoch [145], train_Loss : 0.0329, val_Loss : 0.0559,                train_accuracy : 71.9577%, val_accuracy : 30.0000%
# Epoch [146], train_Loss : 0.0326, val_Loss : 0.0565,                train_accuracy : 71.4286%, val_accuracy : 36.0000%
# Epoch [147], train_Loss : 0.0325, val_Loss : 0.0549,                train_accuracy : 73.0159%, val_accuracy : 28.0000%
# Epoch [148], train_Loss : 0.0328, val_Loss : 0.0561,                train_accuracy : 73.5450%, val_accuracy : 32.0000%
# Epoch [149], train_Loss : 0.0328, val_Loss : 0.0576,                train_accuracy : 71.4286%, val_accuracy : 26.0000%
# Epoch [150], train_Loss : 0.0328, val_Loss : 0.0562,                train_accuracy : 71.9577%, val_accuracy : 34.0000%
# Epoch [151], train_Loss : 0.0330, val_Loss : 0.0576,                train_accuracy : 71.4286%, val_accuracy : 32.0000%
# Epoch [152], train_Loss : 0.0331, val_Loss : 0.0562,                train_accuracy : 71.4286%, val_accuracy : 34.0000%
# Epoch [153], train_Loss : 0.0331, val_Loss : 0.0565,                train_accuracy : 69.8413%, val_accuracy : 34.0000%
# Epoch [154], train_Loss : 0.0343, val_Loss : 0.0560,                train_accuracy : 65.6085%, val_accuracy : 32.0000%
# Epoch [155], train_Loss : 0.0342, val_Loss : 0.0563,                train_accuracy : 67.1958%, val_accuracy : 32.0000%
# Epoch [156], train_Loss : 0.0333, val_Loss : 0.0550,                train_accuracy : 69.3122%, val_accuracy : 30.0000%
# Epoch [157], train_Loss : 0.0321, val_Loss : 0.0562,                train_accuracy : 74.0741%, val_accuracy : 32.0000%
# Epoch [158], train_Loss : 0.0318, val_Loss : 0.0566,                train_accuracy : 75.1323%, val_accuracy : 34.0000%
# Epoch [159], train_Loss : 0.0321, val_Loss : 0.0567,                train_accuracy : 74.0741%, val_accuracy : 32.0000%
# Epoch [160], train_Loss : 0.0320, val_Loss : 0.0558,                train_accuracy : 74.6032%, val_accuracy : 34.0000%
# Epoch [161], train_Loss : 0.0319, val_Loss : 0.0574,                train_accuracy : 75.1323%, val_accuracy : 30.0000%
# Epoch [162], train_Loss : 0.0312, val_Loss : 0.0566,                train_accuracy : 76.7196%, val_accuracy : 34.0000%
# Epoch [163], train_Loss : 0.0316, val_Loss : 0.0571,                train_accuracy : 75.6614%, val_accuracy : 30.0000%
# Epoch [164], train_Loss : 0.0320, val_Loss : 0.0578,                train_accuracy : 74.6032%, val_accuracy : 30.0000%
# Epoch [165], train_Loss : 0.0328, val_Loss : 0.0560,                train_accuracy : 70.8995%, val_accuracy : 34.0000%
# Epoch [166], train_Loss : 0.0328, val_Loss : 0.0558,                train_accuracy : 71.9577%, val_accuracy : 32.0000%
# Epoch [167], train_Loss : 0.0325, val_Loss : 0.0551,                train_accuracy : 72.4868%, val_accuracy : 32.0000%
# Epoch [168], train_Loss : 0.0324, val_Loss : 0.0548,                train_accuracy : 73.0159%, val_accuracy : 34.0000%
# Epoch [169], train_Loss : 0.0331, val_Loss : 0.0581,                train_accuracy : 69.8413%, val_accuracy : 32.0000%
# Epoch [170], train_Loss : 0.0319, val_Loss : 0.0551,                train_accuracy : 74.6032%, val_accuracy : 34.0000%
# Epoch [171], train_Loss : 0.0325, val_Loss : 0.0563,                train_accuracy : 72.4868%, val_accuracy : 32.0000%
# Epoch [172], train_Loss : 0.0321, val_Loss : 0.0566,                train_accuracy : 73.5450%, val_accuracy : 32.0000%
# Epoch [173], train_Loss : 0.0317, val_Loss : 0.0564,                train_accuracy : 75.1323%, val_accuracy : 34.0000%
# Epoch [174], train_Loss : 0.0317, val_Loss : 0.0563,                train_accuracy : 74.6032%, val_accuracy : 32.0000%
# Epoch [175], train_Loss : 0.0316, val_Loss : 0.0555,                train_accuracy : 75.1323%, val_accuracy : 34.0000%
# Epoch [176], train_Loss : 0.0314, val_Loss : 0.0564,                train_accuracy : 76.7196%, val_accuracy : 30.0000%
# Epoch [177], train_Loss : 0.0311, val_Loss : 0.0566,                train_accuracy : 76.7196%, val_accuracy : 32.0000%
# Epoch [178], train_Loss : 0.0310, val_Loss : 0.0572,                train_accuracy : 77.2487%, val_accuracy : 30.0000%
# Epoch [179], train_Loss : 0.0310, val_Loss : 0.0563,                train_accuracy : 77.2487%, val_accuracy : 32.0000%
# Epoch [180], train_Loss : 0.0310, val_Loss : 0.0553,                train_accuracy : 77.7778%, val_accuracy : 34.0000%
# Epoch [181], train_Loss : 0.0312, val_Loss : 0.0552,                train_accuracy : 77.7778%, val_accuracy : 34.0000%
# Epoch [182], train_Loss : 0.0313, val_Loss : 0.0583,                train_accuracy : 76.7196%, val_accuracy : 30.0000%
# Epoch [183], train_Loss : 0.0312, val_Loss : 0.0577,                train_accuracy : 76.7196%, val_accuracy : 32.0000%
# Epoch [184], train_Loss : 0.0310, val_Loss : 0.0582,                train_accuracy : 77.2487%, val_accuracy : 28.0000%
# Epoch [185], train_Loss : 0.0310, val_Loss : 0.0573,                train_accuracy : 77.2487%, val_accuracy : 32.0000%
# Epoch [186], train_Loss : 0.0310, val_Loss : 0.0568,                train_accuracy : 77.7778%, val_accuracy : 32.0000%
# Epoch [187], train_Loss : 0.0309, val_Loss : 0.0588,                train_accuracy : 77.7778%, val_accuracy : 30.0000%
# Epoch [188], train_Loss : 0.0311, val_Loss : 0.0564,                train_accuracy : 77.2487%, val_accuracy : 32.0000%
# Epoch [189], train_Loss : 0.0311, val_Loss : 0.0572,                train_accuracy : 76.7196%, val_accuracy : 32.0000%
# Epoch [190], train_Loss : 0.0308, val_Loss : 0.0573,                train_accuracy : 77.7778%, val_accuracy : 32.0000%
# Epoch [191], train_Loss : 0.0308, val_Loss : 0.0567,                train_accuracy : 77.7778%, val_accuracy : 32.0000%
# Epoch [192], train_Loss : 0.0308, val_Loss : 0.0568,                train_accuracy : 77.7778%, val_accuracy : 32.0000%
# Epoch [193], train_Loss : 0.0308, val_Loss : 0.0567,                train_accuracy : 77.7778%, val_accuracy : 32.0000%
# Epoch [194], train_Loss : 0.0307, val_Loss : 0.0567,                train_accuracy : 77.7778%, val_accuracy : 32.0000%
# Epoch [195], train_Loss : 0.0307, val_Loss : 0.0575,                train_accuracy : 77.7778%, val_accuracy : 30.0000%
# Epoch [196], train_Loss : 0.0308, val_Loss : 0.0570,                train_accuracy : 77.7778%, val_accuracy : 30.0000%
# Epoch [197], train_Loss : 0.0307, val_Loss : 0.0576,                train_accuracy : 77.7778%, val_accuracy : 30.0000%
# Epoch [198], train_Loss : 0.0306, val_Loss : 0.0576,                train_accuracy : 77.7778%, val_accuracy : 30.0000%
# Epoch [199], train_Loss : 0.0307, val_Loss : 0.0571,                train_accuracy : 77.7778%, val_accuracy : 30.0000%
# Epoch [200], train_Loss : 0.0307, val_Loss : 0.0568,                train_accuracy : 77.7778%, val_accuracy : 30.0000%

# %%
model = ViT(patch_h=22, patch_w=2, hidden_d=8, n_blocks=2, n_heads=2).to(device)
model.load_state_dict(torch.load('ViT_subject1.pt'))
model.eval()
test_loss, test_acc = predict(model, optimizer, criterion, test_dataloader)

print(f'Test_Loss : {test_loss:.4f},Test_Accuracy : {100*test_acc:.4f}%')
# Out:
# Test_Loss : 0.0547,Test_Accuracy : 38.0000%

# %%
num_epochs = 200
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)
ax.plot(range(num_epochs), train_loss_list, c='b', label='train loss')
ax.plot(range(num_epochs), test_loss_list, c='r', label='val loss')
ax.set_xlabel('epoch', fontsize='20')
ax.set_ylabel('loss', fontsize='20')
ax.set_title('train and val loss', fontsize='20')
ax.grid()
ax.legend(fontsize='25')
plt.show()

# %%
num_epochs = 200
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)
ax.plot(range(num_epochs), train_acc_list, c='b', label='train accuracy')
ax.plot(range(num_epochs), test_acc_list, c='r', label='val accuracy')
ax.set_xlabel('epoch', fontsize='20')
ax.set_ylabel('loss', fontsize='20')
ax.set_title('train and val accuracy', fontsize='20')
ax.grid()
ax.legend(fontsize='25')
plt.show()

# %%
#!pip install torchsummary
from torchsummary import summary
model = ViT(patch_h=1, patch_w=2, hidden_d=768, n_blocks=12, n_heads=12)
summary(model, (1, 22, 1000))
